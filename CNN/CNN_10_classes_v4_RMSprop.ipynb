# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
from tensorflow.keras import mixed_precision
from tensorflow.keras import layers, regularizers, optimizers
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Load the Food-101 dataset (train split only)
dataset, info = tfds.load("food101", split="train", as_supervised=True, with_info=True)

# Get the class names (only the first 10)
class_names = info.features['label'].names[:10]

# Filter the dataset to keep only the first 10 classes
def filter_classes(image, label):
    return tf.reduce_any([label == i for i in range(10)])

filtered_dataset = dataset.filter(filter_classes)

# Split into train/validation (80% - 20%)
train_split = 0.8
dataset_size = sum(1 for _ in filtered_dataset)
train_size = int(train_split * dataset_size)

train_ds = filtered_dataset.take(train_size)
val_ds = filtered_dataset.skip(train_size)

# Preprocessing function for images
def preprocess(image, label):
    image = tf.image.resize(image, (224, 224)) / 255.0  # Normalisation [0,1]
    return image, label

# Apply preprocessing to datasets
train_ds = train_ds.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
val_ds = val_ds.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)

# Batch and prefetch
batch_size = 64
train_ds = train_ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# Mixed Precision Training
mixed_precision.set_global_policy('mixed_float16')

# %%
# Cnn model
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (5, 5), strides=1, padding='same', activation='relu', input_shape=(224, 224, 3), kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(32, (5, 5), strides=2, padding='same', activation='relu', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Dropout(0.2),

    tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Dropout(0.2),

    tf.keras.layers.Conv2D(128, (2, 2), padding='same', activation='relu', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(128, (2, 2), padding='same', activation='relu', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Dropout(0.2),

    tf.keras.layers.Conv2D(256, (2, 2), padding='same', activation='relu', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(256, (2, 2), padding='same', activation='relu', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.GlobalAveragePooling2D(),

    tf.keras.layers.Dense(512, activation="relu", kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.2),

    tf.keras.layers.Dense(len(class_names), activation="softmax", dtype='float32')  # dtype='float32' pour éviter erreurs Mixed Precision
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# model compilation
model.compile(
    optimizer=tf.keras.optimizers.RMSprop(),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
# Display the model structure
model.summary()
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_66 (Conv2D)                   │ (None, 224, 224, 32)        │           2,432 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_75               │ (None, 224, 224, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_67 (Conv2D)                   │ (None, 112, 112, 32)        │          25,632 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_76               │ (None, 112, 112, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_25 (MaxPooling2D)      │ (None, 56, 56, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_34 (Dropout)                 │ (None, 56, 56, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_68 (Conv2D)                   │ (None, 56, 56, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_77               │ (None, 56, 56, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_69 (Conv2D)                   │ (None, 56, 56, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_78               │ (None, 56, 56, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_26 (MaxPooling2D)      │ (None, 28, 28, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_35 (Dropout)                 │ (None, 28, 28, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_70 (Conv2D)                   │ (None, 28, 28, 128)         │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_79               │ (None, 28, 28, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_71 (Conv2D)                   │ (None, 28, 28, 128)         │          65,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_80               │ (None, 28, 28, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_27 (MaxPooling2D)      │ (None, 14, 14, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_36 (Dropout)                 │ (None, 14, 14, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_72 (Conv2D)                   │ (None, 14, 14, 256)         │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_81               │ (None, 14, 14, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_73 (Conv2D)                   │ (None, 14, 14, 256)         │         262,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_82               │ (None, 14, 14, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_8           │ (None, 256)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_83               │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_37 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 10)                  │           5,130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 718,378 (2.74 MB)
#  Trainable params: 715,434 (2.73 MB)
#  Non-trainable params: 2,944 (11.50 KB)

# %%
# Callbacks to get a better training
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Training of the model
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=100,
    callbacks=[lr_scheduler]
)
# Out:
# Epoch 1/100
#      94/Unknown 33s 203ms/step - accuracy: 0.2170 - loss: 2.6750
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 49s 376ms/step - accuracy: 0.2175 - loss: 2.6716 - val_accuracy: 0.1227 - val_loss: 3.5132 - learning_rate: 0.0010
# Epoch 2/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.3256 - loss: 1.9937 - val_accuracy: 0.1967 - val_loss: 3.1489 - learning_rate: 0.0010
# Epoch 3/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.4171 - loss: 1.7177 - val_accuracy: 0.1520 - val_loss: 2.7476 - learning_rate: 0.0010
# Epoch 4/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.4661 - loss: 1.5691 - val_accuracy: 0.3207 - val_loss: 2.1137 - learning_rate: 0.0010
# Epoch 5/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.4915 - loss: 1.4674 - val_accuracy: 0.3940 - val_loss: 2.0112 - learning_rate: 0.0010
# Epoch 6/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.5339 - loss: 1.3502 - val_accuracy: 0.4193 - val_loss: 1.9473 - learning_rate: 0.0010
# Epoch 7/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.5685 - loss: 1.2695 - val_accuracy: 0.4293 - val_loss: 1.8917 - learning_rate: 0.0010
# Epoch 8/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.5858 - loss: 1.1874 - val_accuracy: 0.4513 - val_loss: 1.8946 - learning_rate: 0.0010
# Epoch 9/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.6127 - loss: 1.1158 - val_accuracy: 0.5113 - val_loss: 1.5607 - learning_rate: 0.0010
# Epoch 10/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.6327 - loss: 1.0515 - val_accuracy: 0.4773 - val_loss: 1.7356 - learning_rate: 0.0010
# Epoch 11/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.6686 - loss: 0.9600 - val_accuracy: 0.4907 - val_loss: 1.7592 - learning_rate: 0.0010
# Epoch 12/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.6849 - loss: 0.9121
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.6849 - loss: 0.9119 - val_accuracy: 0.4813 - val_loss: 1.7512 - learning_rate: 0.0010
# Epoch 13/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.7287 - loss: 0.7744 - val_accuracy: 0.5993 - val_loss: 1.2042 - learning_rate: 5.0000e-04
# Epoch 14/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 267ms/step - accuracy: 0.7503 - loss: 0.7080 - val_accuracy: 0.5893 - val_loss: 1.2839 - learning_rate: 5.0000e-04
# Epoch 15/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 266ms/step - accuracy: 0.7733 - loss: 0.6528 - val_accuracy: 0.5907 - val_loss: 1.2963 - learning_rate: 5.0000e-04
# Epoch 16/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8001 - loss: 0.5944
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.8001 - loss: 0.5941 - val_accuracy: 0.5993 - val_loss: 1.2767 - learning_rate: 5.0000e-04
# Epoch 17/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 266ms/step - accuracy: 0.8199 - loss: 0.5383 - val_accuracy: 0.6207 - val_loss: 1.2368 - learning_rate: 2.5000e-04
# Epoch 18/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.8307 - loss: 0.4860 - val_accuracy: 0.6140 - val_loss: 1.2871 - learning_rate: 2.5000e-04
# Epoch 19/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8446 - loss: 0.4583
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.8447 - loss: 0.4579 - val_accuracy: 0.6333 - val_loss: 1.2112 - learning_rate: 2.5000e-04
# Epoch 20/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.8564 - loss: 0.4124 - val_accuracy: 0.6313 - val_loss: 1.2810 - learning_rate: 1.2500e-04
# Epoch 21/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.8741 - loss: 0.3928 - val_accuracy: 0.6193 - val_loss: 1.3784 - learning_rate: 1.2500e-04
# Epoch 22/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8745 - loss: 0.3763
# Epoch 22: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.8747 - loss: 0.3759 - val_accuracy: 0.6460 - val_loss: 1.2923 - learning_rate: 1.2500e-04
# Epoch 23/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.8829 - loss: 0.3544 - val_accuracy: 0.6380 - val_loss: 1.3140 - learning_rate: 6.2500e-05
# Epoch 24/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.8865 - loss: 0.3388 - val_accuracy: 0.6453 - val_loss: 1.3240 - learning_rate: 6.2500e-05
# Epoch 25/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8958 - loss: 0.3309
# Epoch 25: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.8958 - loss: 0.3306 - val_accuracy: 0.6520 - val_loss: 1.3149 - learning_rate: 6.2500e-05
# Epoch 26/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 266ms/step - accuracy: 0.8938 - loss: 0.3283 - val_accuracy: 0.6500 - val_loss: 1.3097 - learning_rate: 3.1250e-05
# Epoch 27/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.9034 - loss: 0.3041 - val_accuracy: 0.6500 - val_loss: 1.3240 - learning_rate: 3.1250e-05
# Epoch 28/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8995 - loss: 0.3037
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.8996 - loss: 0.3035 - val_accuracy: 0.6493 - val_loss: 1.3040 - learning_rate: 3.1250e-05
# Epoch 29/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.9038 - loss: 0.3001 - val_accuracy: 0.6540 - val_loss: 1.3238 - learning_rate: 1.5625e-05
# Epoch 30/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9001 - loss: 0.3041 - val_accuracy: 0.6513 - val_loss: 1.3291 - learning_rate: 1.5625e-05
# Epoch 31/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9025 - loss: 0.2981
# Epoch 31: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.9026 - loss: 0.2979 - val_accuracy: 0.6507 - val_loss: 1.3402 - learning_rate: 1.5625e-05
# Epoch 32/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.8966 - loss: 0.2953 - val_accuracy: 0.6540 - val_loss: 1.3358 - learning_rate: 7.8125e-06
# Epoch 33/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.9077 - loss: 0.2868 - val_accuracy: 0.6520 - val_loss: 1.3364 - learning_rate: 7.8125e-06
# Epoch 34/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8989 - loss: 0.2969
# Epoch 34: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.8990 - loss: 0.2966 - val_accuracy: 0.6507 - val_loss: 1.3293 - learning_rate: 7.8125e-06
# Epoch 35/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9063 - loss: 0.2828 - val_accuracy: 0.6533 - val_loss: 1.3294 - learning_rate: 3.9063e-06
# Epoch 36/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9050 - loss: 0.2867 - val_accuracy: 0.6540 - val_loss: 1.3320 - learning_rate: 3.9063e-06
# Epoch 37/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9165 - loss: 0.2773
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9166 - loss: 0.2772 - val_accuracy: 0.6547 - val_loss: 1.3349 - learning_rate: 3.9063e-06
# Epoch 38/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 266ms/step - accuracy: 0.9114 - loss: 0.2879 - val_accuracy: 0.6533 - val_loss: 1.3338 - learning_rate: 1.9531e-06
# Epoch 39/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9080 - loss: 0.2810 - val_accuracy: 0.6533 - val_loss: 1.3343 - learning_rate: 1.9531e-06
# Epoch 40/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9139 - loss: 0.2709
# Epoch 40: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.9140 - loss: 0.2708 - val_accuracy: 0.6540 - val_loss: 1.3335 - learning_rate: 1.9531e-06
# Epoch 41/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9061 - loss: 0.2783 - val_accuracy: 0.6527 - val_loss: 1.3330 - learning_rate: 9.7656e-07
# Epoch 42/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9134 - loss: 0.2782 - val_accuracy: 0.6527 - val_loss: 1.3329 - learning_rate: 9.7656e-07
# Epoch 43/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9064 - loss: 0.2924
# Epoch 43: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9066 - loss: 0.2921 - val_accuracy: 0.6527 - val_loss: 1.3339 - learning_rate: 9.7656e-07
# Epoch 44/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9134 - loss: 0.2762 - val_accuracy: 0.6520 - val_loss: 1.3339 - learning_rate: 4.8828e-07
# Epoch 45/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9076 - loss: 0.2793 - val_accuracy: 0.6520 - val_loss: 1.3325 - learning_rate: 4.8828e-07
# Epoch 46/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9039 - loss: 0.2961
# Epoch 46: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.9040 - loss: 0.2958 - val_accuracy: 0.6527 - val_loss: 1.3325 - learning_rate: 4.8828e-07
# Epoch 47/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.9160 - loss: 0.2827 - val_accuracy: 0.6533 - val_loss: 1.3340 - learning_rate: 2.4414e-07
# Epoch 48/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.9125 - loss: 0.2814 - val_accuracy: 0.6527 - val_loss: 1.3338 - learning_rate: 2.4414e-07
# Epoch 49/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9057 - loss: 0.2869
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9058 - loss: 0.2866 - val_accuracy: 0.6527 - val_loss: 1.3354 - learning_rate: 2.4414e-07
# Epoch 50/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9119 - loss: 0.2855 - val_accuracy: 0.6520 - val_loss: 1.3347 - learning_rate: 1.2207e-07
# Epoch 51/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9109 - loss: 0.2739 - val_accuracy: 0.6533 - val_loss: 1.3331 - learning_rate: 1.2207e-07
# Epoch 52/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9102 - loss: 0.2791
# Epoch 52: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9103 - loss: 0.2789 - val_accuracy: 0.6533 - val_loss: 1.3339 - learning_rate: 1.2207e-07
# Epoch 53/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9058 - loss: 0.2897 - val_accuracy: 0.6540 - val_loss: 1.3340 - learning_rate: 6.1035e-08
# Epoch 54/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9096 - loss: 0.2871 - val_accuracy: 0.6533 - val_loss: 1.3336 - learning_rate: 6.1035e-08
# Epoch 55/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9149 - loss: 0.2746
# Epoch 55: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.9149 - loss: 0.2744 - val_accuracy: 0.6540 - val_loss: 1.3336 - learning_rate: 6.1035e-08
# Epoch 56/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9110 - loss: 0.2783 - val_accuracy: 0.6527 - val_loss: 1.3339 - learning_rate: 3.0518e-08
# Epoch 57/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9112 - loss: 0.2819 - val_accuracy: 0.6533 - val_loss: 1.3329 - learning_rate: 3.0518e-08
# Epoch 58/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9136 - loss: 0.2836
# Epoch 58: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.9137 - loss: 0.2833 - val_accuracy: 0.6533 - val_loss: 1.3329 - learning_rate: 3.0518e-08
# Epoch 59/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9101 - loss: 0.2882 - val_accuracy: 0.6527 - val_loss: 1.3329 - learning_rate: 1.5259e-08
# Epoch 60/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9115 - loss: 0.2823 - val_accuracy: 0.6527 - val_loss: 1.3328 - learning_rate: 1.5259e-08
# Epoch 61/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9100 - loss: 0.2776
# Epoch 61: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.9101 - loss: 0.2774 - val_accuracy: 0.6527 - val_loss: 1.3335 - learning_rate: 1.5259e-08
# Epoch 62/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9116 - loss: 0.2786 - val_accuracy: 0.6527 - val_loss: 1.3331 - learning_rate: 7.6294e-09
# Epoch 63/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9137 - loss: 0.2767 - val_accuracy: 0.6533 - val_loss: 1.3329 - learning_rate: 7.6294e-09
# Epoch 64/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9120 - loss: 0.2836
# Epoch 64: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9121 - loss: 0.2834 - val_accuracy: 0.6533 - val_loss: 1.3344 - learning_rate: 7.6294e-09
# Epoch 65/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9070 - loss: 0.2842 - val_accuracy: 0.6533 - val_loss: 1.3343 - learning_rate: 3.8147e-09
# Epoch 66/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.9151 - loss: 0.2777 - val_accuracy: 0.6533 - val_loss: 1.3349 - learning_rate: 3.8147e-09
# Epoch 67/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9147 - loss: 0.2756
# Epoch 67: ReduceLROnPlateau reducing learning rate to 1.907348723406699e-09.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.9148 - loss: 0.2754 - val_accuracy: 0.6527 - val_loss: 1.3354 - learning_rate: 3.8147e-09
# Epoch 68/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9103 - loss: 0.2854 - val_accuracy: 0.6527 - val_loss: 1.3352 - learning_rate: 1.9073e-09
# Epoch 69/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.9108 - loss: 0.2785 - val_accuracy: 0.6520 - val_loss: 1.3342 - learning_rate: 1.9073e-09
# Epoch 70/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9051 - loss: 0.2873
# Epoch 70: ReduceLROnPlateau reducing learning rate to 9.536743617033494e-10.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.9052 - loss: 0.2871 - val_accuracy: 0.6527 - val_loss: 1.3353 - learning_rate: 1.9073e-09
# Epoch 71/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.9110 - loss: 0.2847 - val_accuracy: 0.6540 - val_loss: 1.3343 - learning_rate: 9.5367e-10
# Epoch 72/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.9177 - loss: 0.2691 - val_accuracy: 0.6533 - val_loss: 1.3346 - learning_rate: 9.5367e-10
# Epoch 73/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9123 - loss: 0.2698
# Epoch 73: ReduceLROnPlateau reducing learning rate to 4.768371808516747e-10.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.9124 - loss: 0.2697 - val_accuracy: 0.6533 - val_loss: 1.3346 - learning_rate: 9.5367e-10
# Epoch 74/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9108 - loss: 0.2814 - val_accuracy: 0.6527 - val_loss: 1.3346 - learning_rate: 4.7684e-10
# Epoch 75/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9061 - loss: 0.2829 - val_accuracy: 0.6533 - val_loss: 1.3341 - learning_rate: 4.7684e-10
# Epoch 76/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9126 - loss: 0.2858
# Epoch 76: ReduceLROnPlateau reducing learning rate to 2.3841859042583735e-10.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9127 - loss: 0.2856 - val_accuracy: 0.6533 - val_loss: 1.3345 - learning_rate: 4.7684e-10
# Epoch 77/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9120 - loss: 0.2769 - val_accuracy: 0.6533 - val_loss: 1.3346 - learning_rate: 2.3842e-10
# Epoch 78/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.9180 - loss: 0.2801 - val_accuracy: 0.6527 - val_loss: 1.3347 - learning_rate: 2.3842e-10
# Epoch 79/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9178 - loss: 0.2711
# Epoch 79: ReduceLROnPlateau reducing learning rate to 1.1920929521291868e-10.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9178 - loss: 0.2709 - val_accuracy: 0.6533 - val_loss: 1.3334 - learning_rate: 2.3842e-10
# Epoch 80/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9058 - loss: 0.2782 - val_accuracy: 0.6540 - val_loss: 1.3336 - learning_rate: 1.1921e-10
# Epoch 81/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9089 - loss: 0.2804 - val_accuracy: 0.6520 - val_loss: 1.3355 - learning_rate: 1.1921e-10
# Epoch 82/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9132 - loss: 0.2753
# Epoch 82: ReduceLROnPlateau reducing learning rate to 5.960464760645934e-11.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.9132 - loss: 0.2751 - val_accuracy: 0.6520 - val_loss: 1.3340 - learning_rate: 1.1921e-10
# Epoch 83/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9101 - loss: 0.2788 - val_accuracy: 0.6527 - val_loss: 1.3342 - learning_rate: 5.9605e-11
# Epoch 84/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9099 - loss: 0.2832 - val_accuracy: 0.6533 - val_loss: 1.3349 - learning_rate: 5.9605e-11
# Epoch 85/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9155 - loss: 0.2797
# Epoch 85: ReduceLROnPlateau reducing learning rate to 2.980232380322967e-11.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.9156 - loss: 0.2794 - val_accuracy: 0.6527 - val_loss: 1.3346 - learning_rate: 5.9605e-11
# Epoch 86/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9063 - loss: 0.2838 - val_accuracy: 0.6527 - val_loss: 1.3348 - learning_rate: 2.9802e-11
# Epoch 87/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9120 - loss: 0.2789 - val_accuracy: 0.6520 - val_loss: 1.3348 - learning_rate: 2.9802e-11
# Epoch 88/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9113 - loss: 0.2774
# Epoch 88: ReduceLROnPlateau reducing learning rate to 1.4901161901614834e-11.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9113 - loss: 0.2772 - val_accuracy: 0.6533 - val_loss: 1.3345 - learning_rate: 2.9802e-11
# Epoch 89/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9024 - loss: 0.2844 - val_accuracy: 0.6533 - val_loss: 1.3340 - learning_rate: 1.4901e-11
# Epoch 90/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9074 - loss: 0.2861 - val_accuracy: 0.6533 - val_loss: 1.3343 - learning_rate: 1.4901e-11
# Epoch 91/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9101 - loss: 0.2763
# Epoch 91: ReduceLROnPlateau reducing learning rate to 7.450580950807417e-12.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.9103 - loss: 0.2761 - val_accuracy: 0.6533 - val_loss: 1.3335 - learning_rate: 1.4901e-11
# Epoch 92/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9094 - loss: 0.2810 - val_accuracy: 0.6533 - val_loss: 1.3335 - learning_rate: 7.4506e-12
# Epoch 93/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9111 - loss: 0.2832 - val_accuracy: 0.6533 - val_loss: 1.3339 - learning_rate: 7.4506e-12
# Epoch 94/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9058 - loss: 0.2799
# Epoch 94: ReduceLROnPlateau reducing learning rate to 3.725290475403709e-12.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9059 - loss: 0.2797 - val_accuracy: 0.6520 - val_loss: 1.3345 - learning_rate: 7.4506e-12
# Epoch 95/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9161 - loss: 0.2844 - val_accuracy: 0.6533 - val_loss: 1.3334 - learning_rate: 3.7253e-12
# Epoch 96/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9087 - loss: 0.2857 - val_accuracy: 0.6533 - val_loss: 1.3341 - learning_rate: 3.7253e-12
# Epoch 97/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9074 - loss: 0.2832
# Epoch 97: ReduceLROnPlateau reducing learning rate to 1.8626452377018543e-12.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9076 - loss: 0.2829 - val_accuracy: 0.6527 - val_loss: 1.3345 - learning_rate: 3.7253e-12
# Epoch 98/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9129 - loss: 0.2742 - val_accuracy: 0.6527 - val_loss: 1.3342 - learning_rate: 1.8626e-12
# Epoch 99/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 265ms/step - accuracy: 0.9137 - loss: 0.2771 - val_accuracy: 0.6533 - val_loss: 1.3340 - learning_rate: 1.8626e-12
# Epoch 100/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9108 - loss: 0.2824
# Epoch 100: ReduceLROnPlateau reducing learning rate to 9.313226188509272e-13.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 25s 264ms/step - accuracy: 0.9109 - loss: 0.2821 - val_accuracy: 0.6527 - val_loss: 1.3335 - learning_rate: 1.8626e-12

# %%
# Evaluate the model on the validation dataset
test_loss, test_acc = model.evaluate(val_ds)
print(f'\nValidation Accuracy: {test_acc * 100:.2f}%')
print(f'\nValidation Loss: {test_loss:.4f}')
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 14s 116ms/step - accuracy: 0.6544 - loss: 1.2780
#
# Validation Accuracy: 65.27%
#
# Validation Loss: 1.3335

# %%
import matplotlib.pyplot as plt
# Plots of loss and accuracy
history_dict = history.history
acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']
loss = history_dict['loss']
val_loss = history_dict['val_loss']

plt.figure(figsize=(12, 6))

# Accuracy graph
plt.subplot(1, 2, 1)
plt.plot(acc, label='Accuracy (train)')
plt.plot(val_acc, label='Accuracy (validation)')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Loss graph
plt.subplot(1, 2, 2)
plt.plot(loss, label='Loss (train)')
plt.plot(val_loss, label='Loss (validation)')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
# Classification report
y_pred_probs = model.predict(val_ds)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.concatenate([y for x, y in val_ds], axis=0)

print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_names, digits=4))
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 16s 164ms/step
# Classification Report:
#                    precision    recall  f1-score   support
#
#         apple_pie     0.4074    0.4342    0.4204       152
#    baby_back_ribs     0.7913    0.6741    0.7280       135
#           baklava     0.5371    0.6812    0.6006       138
#    beef_carpaccio     0.7748    0.7548    0.7647       155
#      beef_tartare     0.6379    0.7070    0.6707       157
#        beet_salad     0.8235    0.6806    0.7452       144
#          beignets     0.7967    0.8529    0.8239       170
#          bibimbap     0.8129    0.7590    0.7850       166
#     bread_pudding     0.4538    0.3750    0.4106       144
# breakfast_burrito     0.5203    0.5540    0.5366       139
#
#          accuracy                         0.6527      1500
#         macro avg     0.6556    0.6473    0.6486      1500
#      weighted avg     0.6598    0.6527    0.6535      1500

# %%
#confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
