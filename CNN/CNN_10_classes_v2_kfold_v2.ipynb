# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
from sklearn.model_selection import KFold

# load Food-101 dataset (train only)
dataset, info = tfds.load("food101", split="train", as_supervised=True, with_info=True)

# get classes names
class_names = info.features['label'].names[:10]

# Filtering dataset to get only the first 10 classes
def filter_classes(image, label):
    return tf.reduce_any([label == i for i in range(10)])

filtered_dataset = dataset.filter(filter_classes)

# Preprocessing of images
def preprocess_image(image, label):
    image = tf.image.resize(image, (224, 224))
    return image, label

# Apply preprocessing
filtered_dataset = filtered_dataset.map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)

# Converting dataset into a Numpy array for Kfold
def dataset_to_numpy(dataset):
    images, labels = [], []
    for image, label in dataset:
        images.append(image.numpy())
        labels.append(label.numpy())
    return np.array(images), np.array(labels)

images, labels = dataset_to_numpy(filtered_dataset)

# Kfold
k = 7  # numbers of folds
kfold = KFold(n_splits=k, shuffle=True, random_state=42)

# list to save results
accuracy_per_fold = []
loss_per_fold = []
history_dicts = []

# %%
# Cnn model
def create_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, (5, 5), strides=2, padding='same', activation='relu', input_shape=(224, 224, 3), kernel_initializer='he_normal'),
        tf.keras.layers.Conv2D(32, (5, 5), strides=2, padding='same', activation='relu', kernel_initializer='he_normal'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu', kernel_initializer='he_normal'),
        tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu', kernel_initializer='he_normal'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Conv2D(128, (2, 2), padding='same', activation='relu', kernel_initializer='he_normal'),
        tf.keras.layers.Conv2D(128, (2, 2), padding='same', activation='relu', kernel_initializer='he_normal'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Conv2D(256, (2, 2), padding='same', activation='relu', kernel_initializer='he_normal'),
        tf.keras.layers.Conv2D(256, (2, 2), padding='same', activation='relu', kernel_initializer='he_normal'),
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(512, activation="relu", kernel_initializer='he_normal'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(len(class_names), activation="softmax", kernel_initializer='he_normal')
    ])
    model.compile(optimizer='Adam', loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    return model

# %%
fold_no = 1
for train_idx, val_idx in kfold.split(images, labels):
    train_images, val_images = images[train_idx], images[val_idx]
    train_labels, val_labels = labels[train_idx], labels[val_idx]

    # Creation of the model
    model = create_model()

    # fitting
    history = model.fit(train_images, train_labels, epochs=40, validation_data=(val_images, val_labels), verbose=1,
                       callbacks=[
                           tf.keras.callbacks.ModelCheckpoint(filepath=f'model_fold_{fold_no}.weights.h5', verbose=1, save_best_only=True, save_weights_only=True),
                           tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True),
                           tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
                       ])

    # Evaluation
    test_loss, test_acc = model.evaluate(val_images, val_labels)
    accuracy_per_fold.append(test_acc)
    loss_per_fold.append(test_loss)
    history_dicts.append(history.history)

    print(f'Fold {fold_no} - Accuracy: {test_acc * 100:.2f}% - Loss: {test_loss:.4f}')
    fold_no += 1

# average results
print(f'\nAverage Accuracy: {np.mean(accuracy_per_fold) * 100:.2f}%')
print(f'Average Loss: {np.mean(loss_per_fold):.4f}')
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.1195 - loss: 50.6507
# Epoch 1: val_loss improved from inf to 2.20932, saving model to model_fold_1.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 23s 77ms/step - accuracy: 0.1195 - loss: 50.4595 - val_accuracy: 0.1735 - val_loss: 2.2093 - learning_rate: 0.0010
# Epoch 2/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1547 - loss: 2.1899
# Epoch 2: val_loss improved from 2.20932 to 2.14491, saving model to model_fold_1.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.1548 - loss: 2.1898 - val_accuracy: 0.1744 - val_loss: 2.1449 - learning_rate: 0.0010
# Epoch 3/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1880 - loss: 2.1354
# Epoch 3: val_loss did not improve from 2.14491
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.1880 - loss: 2.1354 - val_accuracy: 0.2043 - val_loss: 2.2055 - learning_rate: 0.0010
# Epoch 4/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1931 - loss: 2.1172
# Epoch 4: val_loss did not improve from 2.14491
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.1932 - loss: 2.1171 - val_accuracy: 0.1614 - val_loss: 2.2567 - learning_rate: 0.0010
# Epoch 5/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2156 - loss: 2.0592
# Epoch 5: val_loss improved from 2.14491 to 2.04662, saving model to model_fold_1.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.2157 - loss: 2.0590 - val_accuracy: 0.1978 - val_loss: 2.0466 - learning_rate: 0.0010
# Epoch 6/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2450 - loss: 1.9950
# Epoch 6: val_loss improved from 2.04662 to 1.98924, saving model to model_fold_1.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.2451 - loss: 1.9951 - val_accuracy: 0.2621 - val_loss: 1.9892 - learning_rate: 0.0010
# Epoch 7/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2772 - loss: 1.9403
# Epoch 7: val_loss improved from 1.98924 to 1.91117, saving model to model_fold_1.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.2773 - loss: 1.9403 - val_accuracy: 0.2910 - val_loss: 1.9112 - learning_rate: 0.0010
# Epoch 8/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2862 - loss: 1.9051
# Epoch 8: val_loss improved from 1.91117 to 1.87868, saving model to model_fold_1.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.2862 - loss: 1.9052 - val_accuracy: 0.3106 - val_loss: 1.8787 - learning_rate: 0.0010
# Epoch 9/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3173 - loss: 1.8718
# Epoch 9: val_loss improved from 1.87868 to 1.86871, saving model to model_fold_1.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3171 - loss: 1.8717 - val_accuracy: 0.3004 - val_loss: 1.8687 - learning_rate: 0.0010
# Epoch 10/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3047 - loss: 1.8692
# Epoch 10: val_loss improved from 1.86871 to 1.83165, saving model to model_fold_1.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3048 - loss: 1.8691 - val_accuracy: 0.3200 - val_loss: 1.8316 - learning_rate: 0.0010
# Epoch 11/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3297 - loss: 1.8213
# Epoch 11: val_loss did not improve from 1.83165
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3296 - loss: 1.8215 - val_accuracy: 0.3004 - val_loss: 1.9227 - learning_rate: 0.0010
# Epoch 12/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3266 - loss: 1.8272
# Epoch 12: val_loss improved from 1.83165 to 1.78039, saving model to model_fold_1.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3267 - loss: 1.8271 - val_accuracy: 0.3769 - val_loss: 1.7804 - learning_rate: 0.0010
# Epoch 13/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3333 - loss: 1.8023
# Epoch 13: val_loss did not improve from 1.78039
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3333 - loss: 1.8023 - val_accuracy: 0.3563 - val_loss: 1.7966 - learning_rate: 0.0010
# Epoch 14/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3412 - loss: 1.7772
# Epoch 14: val_loss did not improve from 1.78039
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3414 - loss: 1.7770 - val_accuracy: 0.3377 - val_loss: 1.7966 - learning_rate: 0.0010
# Epoch 15/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3692 - loss: 1.7395
# Epoch 15: val_loss did not improve from 1.78039
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3692 - loss: 1.7396 - val_accuracy: 0.3340 - val_loss: 1.8246 - learning_rate: 0.0010
# Epoch 16/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3673 - loss: 1.7180
# Epoch 16: val_loss did not improve from 1.78039
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3674 - loss: 1.7180 - val_accuracy: 0.3405 - val_loss: 1.8517 - learning_rate: 0.0010
# Epoch 17/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3911 - loss: 1.6877
# Epoch 17: val_loss improved from 1.78039 to 1.77284, saving model to model_fold_1.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3910 - loss: 1.6878 - val_accuracy: 0.3424 - val_loss: 1.7728 - learning_rate: 0.0010
# Epoch 18/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3777 - loss: 1.6956
# Epoch 18: val_loss improved from 1.77284 to 1.75280, saving model to model_fold_1.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3777 - loss: 1.6955 - val_accuracy: 0.3713 - val_loss: 1.7528 - learning_rate: 0.0010
# Epoch 19/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3969 - loss: 1.6459
# Epoch 19: val_loss improved from 1.75280 to 1.69585, saving model to model_fold_1.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3968 - loss: 1.6460 - val_accuracy: 0.4039 - val_loss: 1.6958 - learning_rate: 0.0010
# Epoch 20/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3984 - loss: 1.6634
# Epoch 20: val_loss did not improve from 1.69585
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3983 - loss: 1.6633 - val_accuracy: 0.3619 - val_loss: 1.7787 - learning_rate: 0.0010
# Epoch 21/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4082 - loss: 1.6415
# Epoch 21: val_loss did not improve from 1.69585
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4081 - loss: 1.6415 - val_accuracy: 0.3778 - val_loss: 1.7526 - learning_rate: 0.0010
# Epoch 22/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4123 - loss: 1.6078
# Epoch 22: val_loss did not improve from 1.69585
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4121 - loss: 1.6080 - val_accuracy: 0.3825 - val_loss: 1.7191 - learning_rate: 0.0010
# Epoch 23/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4271 - loss: 1.5703
# Epoch 23: val_loss improved from 1.69585 to 1.67353, saving model to model_fold_1.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4269 - loss: 1.5710 - val_accuracy: 0.4039 - val_loss: 1.6735 - learning_rate: 0.0010
# Epoch 24/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4134 - loss: 1.5926
# Epoch 24: val_loss did not improve from 1.67353
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4136 - loss: 1.5927 - val_accuracy: 0.3890 - val_loss: 1.6984 - learning_rate: 0.0010
# Epoch 25/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4240 - loss: 1.5783
# Epoch 25: val_loss did not improve from 1.67353
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4240 - loss: 1.5784 - val_accuracy: 0.3853 - val_loss: 1.8100 - learning_rate: 0.0010
# Epoch 26/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4507 - loss: 1.5188
# Epoch 26: val_loss did not improve from 1.67353
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4505 - loss: 1.5192 - val_accuracy: 0.4188 - val_loss: 1.7023 - learning_rate: 0.0010
# Epoch 27/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4379 - loss: 1.5344
# Epoch 27: val_loss improved from 1.67353 to 1.67180, saving model to model_fold_1.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4378 - loss: 1.5348 - val_accuracy: 0.4058 - val_loss: 1.6718 - learning_rate: 0.0010
# Epoch 28/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4426 - loss: 1.5078
# Epoch 28: val_loss did not improve from 1.67180
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4425 - loss: 1.5081 - val_accuracy: 0.3937 - val_loss: 1.6774 - learning_rate: 0.0010
# Epoch 29/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4494 - loss: 1.5127
# Epoch 29: val_loss improved from 1.67180 to 1.65020, saving model to model_fold_1.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4492 - loss: 1.5131 - val_accuracy: 0.4104 - val_loss: 1.6502 - learning_rate: 0.0010
# Epoch 30/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4580 - loss: 1.5173
# Epoch 30: val_loss did not improve from 1.65020
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4579 - loss: 1.5174 - val_accuracy: 0.4132 - val_loss: 1.6634 - learning_rate: 0.0010
# Epoch 31/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4673 - loss: 1.4844
# Epoch 31: val_loss improved from 1.65020 to 1.64950, saving model to model_fold_1.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4673 - loss: 1.4844 - val_accuracy: 0.4226 - val_loss: 1.6495 - learning_rate: 0.0010
# Epoch 32/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4746 - loss: 1.4579
# Epoch 32: val_loss did not improve from 1.64950
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4747 - loss: 1.4581 - val_accuracy: 0.4142 - val_loss: 1.6748 - learning_rate: 0.0010
# Epoch 33/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4819 - loss: 1.4620
# Epoch 33: val_loss improved from 1.64950 to 1.59883, saving model to model_fold_1.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4819 - loss: 1.4620 - val_accuracy: 0.4254 - val_loss: 1.5988 - learning_rate: 0.0010
# Epoch 34/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4731 - loss: 1.4612
# Epoch 34: val_loss improved from 1.59883 to 1.58609, saving model to model_fold_1.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4732 - loss: 1.4611 - val_accuracy: 0.4403 - val_loss: 1.5861 - learning_rate: 0.0010
# Epoch 35/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4881 - loss: 1.4147
# Epoch 35: val_loss did not improve from 1.58609
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4881 - loss: 1.4148 - val_accuracy: 0.3983 - val_loss: 1.7630 - learning_rate: 0.0010
# Epoch 36/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4906 - loss: 1.4100
# Epoch 36: val_loss improved from 1.58609 to 1.57538, saving model to model_fold_1.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4906 - loss: 1.4101 - val_accuracy: 0.4375 - val_loss: 1.5754 - learning_rate: 0.0010
# Epoch 37/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5079 - loss: 1.3791
# Epoch 37: val_loss did not improve from 1.57538
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5075 - loss: 1.3799 - val_accuracy: 0.4487 - val_loss: 1.6016 - learning_rate: 0.0010
# Epoch 38/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4928 - loss: 1.3961
# Epoch 38: val_loss did not improve from 1.57538
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4930 - loss: 1.3959 - val_accuracy: 0.4132 - val_loss: 1.6696 - learning_rate: 0.0010
# Epoch 39/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5118 - loss: 1.3501
# Epoch 39: val_loss did not improve from 1.57538
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5118 - loss: 1.3503 - val_accuracy: 0.4394 - val_loss: 1.6274 - learning_rate: 0.0010
# Epoch 40/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5001 - loss: 1.3744
# Epoch 40: val_loss did not improve from 1.57538
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5001 - loss: 1.3743 - val_accuracy: 0.4338 - val_loss: 1.6271 - learning_rate: 0.0010
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4425 - loss: 1.5654
# Fold 1 - Accuracy: 43.75% - Loss: 1.5754
# Epoch 1/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.1288 - loss: 36.6317
# Epoch 1: val_loss improved from inf to 2.14918, saving model to model_fold_2.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 18s 50ms/step - accuracy: 0.1288 - loss: 36.4944 - val_accuracy: 0.1567 - val_loss: 2.1492 - learning_rate: 0.0010
# Epoch 2/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1654 - loss: 2.1675
# Epoch 2: val_loss improved from 2.14918 to 2.07530, saving model to model_fold_2.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.1655 - loss: 2.1673 - val_accuracy: 0.1772 - val_loss: 2.0753 - learning_rate: 0.0010
# Epoch 3/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2080 - loss: 2.0661
# Epoch 3: val_loss improved from 2.07530 to 1.99528, saving model to model_fold_2.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.2080 - loss: 2.0660 - val_accuracy: 0.2425 - val_loss: 1.9953 - learning_rate: 0.0010
# Epoch 4/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2330 - loss: 1.9909
# Epoch 4: val_loss improved from 1.99528 to 1.94971, saving model to model_fold_2.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.2330 - loss: 1.9913 - val_accuracy: 0.2780 - val_loss: 1.9497 - learning_rate: 0.0010
# Epoch 5/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2589 - loss: 1.9586
# Epoch 5: val_loss did not improve from 1.94971
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.2588 - loss: 1.9589 - val_accuracy: 0.2276 - val_loss: 2.0016 - learning_rate: 0.0010
# Epoch 6/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2496 - loss: 1.9736
# Epoch 6: val_loss improved from 1.94971 to 1.91872, saving model to model_fold_2.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.2498 - loss: 1.9734 - val_accuracy: 0.2509 - val_loss: 1.9187 - learning_rate: 0.0010
# Epoch 7/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2684 - loss: 1.9164
# Epoch 7: val_loss improved from 1.91872 to 1.89626, saving model to model_fold_2.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.2684 - loss: 1.9164 - val_accuracy: 0.2743 - val_loss: 1.8963 - learning_rate: 0.0010
# Epoch 8/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2969 - loss: 1.8881
# Epoch 8: val_loss improved from 1.89626 to 1.85069, saving model to model_fold_2.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.2968 - loss: 1.8881 - val_accuracy: 0.3181 - val_loss: 1.8507 - learning_rate: 0.0010
# Epoch 9/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2951 - loss: 1.8442
# Epoch 9: val_loss did not improve from 1.85069
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.2952 - loss: 1.8440 - val_accuracy: 0.3032 - val_loss: 1.9053 - learning_rate: 0.0010
# Epoch 10/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3272 - loss: 1.8029
# Epoch 10: val_loss improved from 1.85069 to 1.81691, saving model to model_fold_2.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3274 - loss: 1.8026 - val_accuracy: 0.3302 - val_loss: 1.8169 - learning_rate: 0.0010
# Epoch 11/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3396 - loss: 1.7831
# Epoch 11: val_loss improved from 1.81691 to 1.74572, saving model to model_fold_2.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3396 - loss: 1.7827 - val_accuracy: 0.3685 - val_loss: 1.7457 - learning_rate: 0.0010
# Epoch 12/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3616 - loss: 1.7044
# Epoch 12: val_loss did not improve from 1.74572
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3616 - loss: 1.7045 - val_accuracy: 0.2715 - val_loss: 1.9013 - learning_rate: 0.0010
# Epoch 13/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3546 - loss: 1.7070
# Epoch 13: val_loss did not improve from 1.74572
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3548 - loss: 1.7070 - val_accuracy: 0.3563 - val_loss: 1.7554 - learning_rate: 0.0010
# Epoch 14/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3789 - loss: 1.6783
# Epoch 14: val_loss improved from 1.74572 to 1.68886, saving model to model_fold_2.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3789 - loss: 1.6783 - val_accuracy: 0.3899 - val_loss: 1.6889 - learning_rate: 0.0010
# Epoch 15/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3789 - loss: 1.6679
# Epoch 15: val_loss improved from 1.68886 to 1.67366, saving model to model_fold_2.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3790 - loss: 1.6675 - val_accuracy: 0.4067 - val_loss: 1.6737 - learning_rate: 0.0010
# Epoch 16/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4044 - loss: 1.6055
# Epoch 16: val_loss did not improve from 1.67366
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4044 - loss: 1.6058 - val_accuracy: 0.3815 - val_loss: 1.6756 - learning_rate: 0.0010
# Epoch 17/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4019 - loss: 1.6337
# Epoch 17: val_loss did not improve from 1.67366
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4020 - loss: 1.6334 - val_accuracy: 0.3349 - val_loss: 1.7665 - learning_rate: 0.0010
# Epoch 18/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4084 - loss: 1.6018
# Epoch 18: val_loss did not improve from 1.67366
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4084 - loss: 1.6019 - val_accuracy: 0.4030 - val_loss: 1.6747 - learning_rate: 0.0010
# Epoch 19/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4376 - loss: 1.5654
# Epoch 19: val_loss improved from 1.67366 to 1.58873, saving model to model_fold_2.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4376 - loss: 1.5654 - val_accuracy: 0.4254 - val_loss: 1.5887 - learning_rate: 0.0010
# Epoch 20/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4285 - loss: 1.5528
# Epoch 20: val_loss did not improve from 1.58873
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4285 - loss: 1.5531 - val_accuracy: 0.4132 - val_loss: 1.6292 - learning_rate: 0.0010
# Epoch 21/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4368 - loss: 1.5371
# Epoch 21: val_loss did not improve from 1.58873
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4368 - loss: 1.5374 - val_accuracy: 0.4412 - val_loss: 1.5922 - learning_rate: 0.0010
# Epoch 22/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4484 - loss: 1.5225
# Epoch 22: val_loss did not improve from 1.58873
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4484 - loss: 1.5226 - val_accuracy: 0.4132 - val_loss: 1.5966 - learning_rate: 0.0010
# Epoch 23/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4536 - loss: 1.5011
# Epoch 23: val_loss did not improve from 1.58873
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4535 - loss: 1.5012 - val_accuracy: 0.3965 - val_loss: 1.6559 - learning_rate: 0.0010
# Epoch 24/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4582 - loss: 1.4920
# Epoch 24: val_loss improved from 1.58873 to 1.52777, saving model to model_fold_2.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4580 - loss: 1.4924 - val_accuracy: 0.4468 - val_loss: 1.5278 - learning_rate: 0.0010
# Epoch 25/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4652 - loss: 1.4964
# Epoch 25: val_loss did not improve from 1.52777
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4651 - loss: 1.4964 - val_accuracy: 0.4356 - val_loss: 1.5606 - learning_rate: 0.0010
# Epoch 26/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4757 - loss: 1.4364
# Epoch 26: val_loss did not improve from 1.52777
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4757 - loss: 1.4365 - val_accuracy: 0.4431 - val_loss: 1.5507 - learning_rate: 0.0010
# Epoch 27/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4861 - loss: 1.4267
# Epoch 27: val_loss did not improve from 1.52777
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4859 - loss: 1.4273 - val_accuracy: 0.4198 - val_loss: 1.5765 - learning_rate: 0.0010
# Epoch 28/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4756 - loss: 1.4310
# Epoch 28: val_loss did not improve from 1.52777
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4756 - loss: 1.4311 - val_accuracy: 0.4198 - val_loss: 1.5821 - learning_rate: 0.0010
# Epoch 29/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4786 - loss: 1.4476
# Epoch 29: val_loss did not improve from 1.52777
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4787 - loss: 1.4475 - val_accuracy: 0.4263 - val_loss: 1.6164 - learning_rate: 0.0010
# Epoch 30/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4893 - loss: 1.4128
# Epoch 30: val_loss did not improve from 1.52777
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4893 - loss: 1.4128 - val_accuracy: 0.4506 - val_loss: 1.5567 - learning_rate: 0.0010
# Epoch 31/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5112 - loss: 1.3802
# Epoch 31: val_loss improved from 1.52777 to 1.50897, saving model to model_fold_2.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5111 - loss: 1.3803 - val_accuracy: 0.4468 - val_loss: 1.5090 - learning_rate: 0.0010
# Epoch 32/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5015 - loss: 1.3567
# Epoch 32: val_loss did not improve from 1.50897
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5015 - loss: 1.3568 - val_accuracy: 0.4590 - val_loss: 1.5188 - learning_rate: 0.0010
# Epoch 33/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5218 - loss: 1.3187
# Epoch 33: val_loss improved from 1.50897 to 1.47668, saving model to model_fold_2.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5217 - loss: 1.3191 - val_accuracy: 0.4935 - val_loss: 1.4767 - learning_rate: 0.0010
# Epoch 34/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5137 - loss: 1.3446
# Epoch 34: val_loss did not improve from 1.47668
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5137 - loss: 1.3446 - val_accuracy: 0.4375 - val_loss: 1.5633 - learning_rate: 0.0010
# Epoch 35/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5237 - loss: 1.3216
# Epoch 35: val_loss did not improve from 1.47668
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5236 - loss: 1.3219 - val_accuracy: 0.4543 - val_loss: 1.5792 - learning_rate: 0.0010
# Epoch 36/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5368 - loss: 1.2867
# Epoch 36: val_loss did not improve from 1.47668
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5367 - loss: 1.2870 - val_accuracy: 0.4431 - val_loss: 1.5546 - learning_rate: 0.0010
# Epoch 37/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5284 - loss: 1.2866
# Epoch 37: val_loss did not improve from 1.47668
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5284 - loss: 1.2866 - val_accuracy: 0.4701 - val_loss: 1.4943 - learning_rate: 0.0010
# Epoch 38/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5403 - loss: 1.2697
# Epoch 38: val_loss did not improve from 1.47668
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5403 - loss: 1.2696 - val_accuracy: 0.4487 - val_loss: 1.5655 - learning_rate: 0.0010
# Epoch 39/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5432 - loss: 1.2464
# Epoch 39: val_loss did not improve from 1.47668
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5431 - loss: 1.2467 - val_accuracy: 0.4468 - val_loss: 1.5024 - learning_rate: 0.0010
# Epoch 40/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5385 - loss: 1.2732
# Epoch 40: val_loss did not improve from 1.47668
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5385 - loss: 1.2731 - val_accuracy: 0.4674 - val_loss: 1.4946 - learning_rate: 0.0010
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4660 - loss: 1.4902
# Fold 2 - Accuracy: 49.35% - Loss: 1.4767
# Epoch 1/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.1237 - loss: 52.6584
# Epoch 1: val_loss improved from inf to 2.20189, saving model to model_fold_3.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 18s 50ms/step - accuracy: 0.1238 - loss: 52.4591 - val_accuracy: 0.1614 - val_loss: 2.2019 - learning_rate: 0.0010
# Epoch 2/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1626 - loss: 2.1838
# Epoch 2: val_loss did not improve from 2.20189
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.1627 - loss: 2.1838 - val_accuracy: 0.1297 - val_loss: 2.2501 - learning_rate: 0.0010
# Epoch 3/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1811 - loss: 2.1651
# Epoch 3: val_loss improved from 2.20189 to 2.12265, saving model to model_fold_3.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.1811 - loss: 2.1650 - val_accuracy: 0.1772 - val_loss: 2.1227 - learning_rate: 0.0010
# Epoch 4/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2133 - loss: 2.0947
# Epoch 4: val_loss improved from 2.12265 to 2.04925, saving model to model_fold_3.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.2133 - loss: 2.0947 - val_accuracy: 0.2174 - val_loss: 2.0492 - learning_rate: 0.0010
# Epoch 5/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2271 - loss: 2.0353
# Epoch 5: val_loss improved from 2.04925 to 2.04082, saving model to model_fold_3.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.2271 - loss: 2.0353 - val_accuracy: 0.2146 - val_loss: 2.0408 - learning_rate: 0.0010
# Epoch 6/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2555 - loss: 1.9696
# Epoch 6: val_loss improved from 2.04082 to 1.99923, saving model to model_fold_3.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.2556 - loss: 1.9697 - val_accuracy: 0.2304 - val_loss: 1.9992 - learning_rate: 0.0010
# Epoch 7/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2788 - loss: 1.9301
# Epoch 7: val_loss improved from 1.99923 to 1.93974, saving model to model_fold_3.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.2787 - loss: 1.9301 - val_accuracy: 0.2761 - val_loss: 1.9397 - learning_rate: 0.0010
# Epoch 8/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2839 - loss: 1.8983
# Epoch 8: val_loss improved from 1.93974 to 1.89965, saving model to model_fold_3.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.2840 - loss: 1.8982 - val_accuracy: 0.2994 - val_loss: 1.8996 - learning_rate: 0.0010
# Epoch 9/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3022 - loss: 1.8727
# Epoch 9: val_loss did not improve from 1.89965
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3021 - loss: 1.8730 - val_accuracy: 0.2621 - val_loss: 1.9547 - learning_rate: 0.0010
# Epoch 10/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3078 - loss: 1.8371
# Epoch 10: val_loss improved from 1.89965 to 1.87042, saving model to model_fold_3.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3080 - loss: 1.8370 - val_accuracy: 0.2948 - val_loss: 1.8704 - learning_rate: 0.0010
# Epoch 11/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3199 - loss: 1.8218
# Epoch 11: val_loss improved from 1.87042 to 1.81924, saving model to model_fold_3.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3199 - loss: 1.8216 - val_accuracy: 0.3153 - val_loss: 1.8192 - learning_rate: 0.0010
# Epoch 12/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3427 - loss: 1.7738
# Epoch 12: val_loss did not improve from 1.81924
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3426 - loss: 1.7744 - val_accuracy: 0.3162 - val_loss: 1.8295 - learning_rate: 0.0010
# Epoch 13/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3573 - loss: 1.7655
# Epoch 13: val_loss improved from 1.81924 to 1.79218, saving model to model_fold_3.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3573 - loss: 1.7655 - val_accuracy: 0.3293 - val_loss: 1.7922 - learning_rate: 0.0010
# Epoch 14/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3638 - loss: 1.7538
# Epoch 14: val_loss improved from 1.79218 to 1.73933, saving model to model_fold_3.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3636 - loss: 1.7538 - val_accuracy: 0.3657 - val_loss: 1.7393 - learning_rate: 0.0010
# Epoch 15/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3721 - loss: 1.7171
# Epoch 15: val_loss did not improve from 1.73933
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3720 - loss: 1.7175 - val_accuracy: 0.3321 - val_loss: 1.8064 - learning_rate: 0.0010
# Epoch 16/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3595 - loss: 1.7570
# Epoch 16: val_loss did not improve from 1.73933
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3596 - loss: 1.7568 - val_accuracy: 0.3433 - val_loss: 1.7794 - learning_rate: 0.0010
# Epoch 17/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3603 - loss: 1.7449
# Epoch 17: val_loss did not improve from 1.73933
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3604 - loss: 1.7447 - val_accuracy: 0.3414 - val_loss: 1.7689 - learning_rate: 0.0010
# Epoch 18/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3775 - loss: 1.7055
# Epoch 18: val_loss improved from 1.73933 to 1.73140, saving model to model_fold_3.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3775 - loss: 1.7054 - val_accuracy: 0.3470 - val_loss: 1.7314 - learning_rate: 0.0010
# Epoch 19/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3883 - loss: 1.6800
# Epoch 19: val_loss improved from 1.73140 to 1.72875, saving model to model_fold_3.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3884 - loss: 1.6799 - val_accuracy: 0.3619 - val_loss: 1.7288 - learning_rate: 0.0010
# Epoch 20/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3961 - loss: 1.6529
# Epoch 20: val_loss did not improve from 1.72875
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3960 - loss: 1.6531 - val_accuracy: 0.3507 - val_loss: 1.7373 - learning_rate: 0.0010
# Epoch 21/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3859 - loss: 1.6675
# Epoch 21: val_loss did not improve from 1.72875
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3860 - loss: 1.6674 - val_accuracy: 0.3694 - val_loss: 1.7549 - learning_rate: 0.0010
# Epoch 22/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3989 - loss: 1.6440
# Epoch 22: val_loss improved from 1.72875 to 1.71705, saving model to model_fold_3.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3988 - loss: 1.6441 - val_accuracy: 0.3545 - val_loss: 1.7170 - learning_rate: 0.0010
# Epoch 23/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4180 - loss: 1.6167
# Epoch 23: val_loss improved from 1.71705 to 1.66703, saving model to model_fold_3.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4179 - loss: 1.6168 - val_accuracy: 0.3937 - val_loss: 1.6670 - learning_rate: 0.0010
# Epoch 24/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4040 - loss: 1.6128
# Epoch 24: val_loss did not improve from 1.66703
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4039 - loss: 1.6130 - val_accuracy: 0.3797 - val_loss: 1.6888 - learning_rate: 0.0010
# Epoch 25/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4202 - loss: 1.5940
# Epoch 25: val_loss did not improve from 1.66703
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4201 - loss: 1.5940 - val_accuracy: 0.3843 - val_loss: 1.6712 - learning_rate: 0.0010
# Epoch 26/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4179 - loss: 1.5882
# Epoch 26: val_loss did not improve from 1.66703
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4179 - loss: 1.5883 - val_accuracy: 0.3871 - val_loss: 1.6885 - learning_rate: 0.0010
# Epoch 27/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4218 - loss: 1.6006
# Epoch 27: val_loss improved from 1.66703 to 1.64120, saving model to model_fold_3.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4218 - loss: 1.6005 - val_accuracy: 0.3909 - val_loss: 1.6412 - learning_rate: 0.0010
# Epoch 28/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4436 - loss: 1.5468
# Epoch 28: val_loss did not improve from 1.64120
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4435 - loss: 1.5470 - val_accuracy: 0.3797 - val_loss: 1.6832 - learning_rate: 0.0010
# Epoch 29/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4475 - loss: 1.5445
# Epoch 29: val_loss improved from 1.64120 to 1.62671, saving model to model_fold_3.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4472 - loss: 1.5449 - val_accuracy: 0.4235 - val_loss: 1.6267 - learning_rate: 0.0010
# Epoch 30/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4432 - loss: 1.5326
# Epoch 30: val_loss did not improve from 1.62671
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4431 - loss: 1.5328 - val_accuracy: 0.3909 - val_loss: 1.6904 - learning_rate: 0.0010
# Epoch 31/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4456 - loss: 1.5469
# Epoch 31: val_loss did not improve from 1.62671
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4456 - loss: 1.5468 - val_accuracy: 0.3759 - val_loss: 1.6863 - learning_rate: 0.0010
# Epoch 32/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4438 - loss: 1.5296
# Epoch 32: val_loss improved from 1.62671 to 1.60474, saving model to model_fold_3.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4438 - loss: 1.5294 - val_accuracy: 0.4198 - val_loss: 1.6047 - learning_rate: 0.0010
# Epoch 33/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4523 - loss: 1.4906
# Epoch 33: val_loss did not improve from 1.60474
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4522 - loss: 1.4909 - val_accuracy: 0.3881 - val_loss: 1.6805 - learning_rate: 0.0010
# Epoch 34/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4694 - loss: 1.5051
# Epoch 34: val_loss improved from 1.60474 to 1.58761, saving model to model_fold_3.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4694 - loss: 1.5051 - val_accuracy: 0.4263 - val_loss: 1.5876 - learning_rate: 0.0010
# Epoch 35/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4527 - loss: 1.5105
# Epoch 35: val_loss did not improve from 1.58761
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4530 - loss: 1.5102 - val_accuracy: 0.4114 - val_loss: 1.5923 - learning_rate: 0.0010
# Epoch 36/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4594 - loss: 1.5049
# Epoch 36: val_loss did not improve from 1.58761
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4595 - loss: 1.5044 - val_accuracy: 0.4039 - val_loss: 1.6200 - learning_rate: 0.0010
# Epoch 37/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4584 - loss: 1.4896
# Epoch 37: val_loss did not improve from 1.58761
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4585 - loss: 1.4895 - val_accuracy: 0.4188 - val_loss: 1.5910 - learning_rate: 0.0010
# Epoch 38/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4937 - loss: 1.4220
# Epoch 38: val_loss improved from 1.58761 to 1.56545, saving model to model_fold_3.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4936 - loss: 1.4222 - val_accuracy: 0.4328 - val_loss: 1.5654 - learning_rate: 0.0010
# Epoch 39/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4800 - loss: 1.4416
# Epoch 39: val_loss improved from 1.56545 to 1.56242, saving model to model_fold_3.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4799 - loss: 1.4420 - val_accuracy: 0.4338 - val_loss: 1.5624 - learning_rate: 0.0010
# Epoch 40/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4905 - loss: 1.4315
# Epoch 40: val_loss did not improve from 1.56242
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4904 - loss: 1.4316 - val_accuracy: 0.4263 - val_loss: 1.5694 - learning_rate: 0.0010
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4049 - loss: 1.6227
# Fold 3 - Accuracy: 43.38% - Loss: 1.5624
# Epoch 1/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.1126 - loss: 42.3032
# Epoch 1: val_loss improved from inf to 2.17553, saving model to model_fold_4.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 25s 84ms/step - accuracy: 0.1127 - loss: 42.1456 - val_accuracy: 0.1802 - val_loss: 2.1755 - learning_rate: 0.0010
# Epoch 2/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1870 - loss: 2.1549
# Epoch 2: val_loss improved from 2.17553 to 2.04604, saving model to model_fold_4.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.1870 - loss: 2.1547 - val_accuracy: 0.2241 - val_loss: 2.0460 - learning_rate: 0.0010
# Epoch 3/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2158 - loss: 2.0535
# Epoch 3: val_loss did not improve from 2.04604
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.2159 - loss: 2.0534 - val_accuracy: 0.2428 - val_loss: 2.0754 - learning_rate: 0.0010
# Epoch 4/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2432 - loss: 2.0096
# Epoch 4: val_loss did not improve from 2.04604
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.2434 - loss: 2.0091 - val_accuracy: 0.2736 - val_loss: 2.0485 - learning_rate: 0.0010
# Epoch 5/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2838 - loss: 1.9373
# Epoch 5: val_loss improved from 2.04604 to 1.98061, saving model to model_fold_4.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.2836 - loss: 1.9377 - val_accuracy: 0.2568 - val_loss: 1.9806 - learning_rate: 0.0010
# Epoch 6/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2762 - loss: 1.9626
# Epoch 6: val_loss improved from 1.98061 to 1.84412, saving model to model_fold_4.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.2762 - loss: 1.9620 - val_accuracy: 0.3287 - val_loss: 1.8441 - learning_rate: 0.0010
# Epoch 7/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3162 - loss: 1.8609
# Epoch 7: val_loss improved from 1.84412 to 1.77942, saving model to model_fold_4.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3165 - loss: 1.8604 - val_accuracy: 0.3557 - val_loss: 1.7794 - learning_rate: 0.0010
# Epoch 8/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3339 - loss: 1.8055
# Epoch 8: val_loss did not improve from 1.77942
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3340 - loss: 1.8055 - val_accuracy: 0.3053 - val_loss: 1.8851 - learning_rate: 0.0010
# Epoch 9/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3519 - loss: 1.7883
# Epoch 9: val_loss did not improve from 1.77942
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3517 - loss: 1.7882 - val_accuracy: 0.3165 - val_loss: 1.8549 - learning_rate: 0.0010
# Epoch 10/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3521 - loss: 1.7545
# Epoch 10: val_loss improved from 1.77942 to 1.71817, saving model to model_fold_4.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3521 - loss: 1.7543 - val_accuracy: 0.3800 - val_loss: 1.7182 - learning_rate: 0.0010
# Epoch 11/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3616 - loss: 1.7075
# Epoch 11: val_loss did not improve from 1.71817
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3618 - loss: 1.7075 - val_accuracy: 0.3268 - val_loss: 1.8173 - learning_rate: 0.0010
# Epoch 12/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3745 - loss: 1.7018
# Epoch 12: val_loss improved from 1.71817 to 1.66196, saving model to model_fold_4.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3745 - loss: 1.7018 - val_accuracy: 0.4024 - val_loss: 1.6620 - learning_rate: 0.0010
# Epoch 13/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3832 - loss: 1.6789
# Epoch 13: val_loss did not improve from 1.66196
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3832 - loss: 1.6789 - val_accuracy: 0.3978 - val_loss: 1.7388 - learning_rate: 0.0010
# Epoch 14/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3871 - loss: 1.6607
# Epoch 14: val_loss did not improve from 1.66196
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3871 - loss: 1.6606 - val_accuracy: 0.4071 - val_loss: 1.6732 - learning_rate: 0.0010
# Epoch 15/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4143 - loss: 1.6070
# Epoch 15: val_loss did not improve from 1.66196
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4140 - loss: 1.6078 - val_accuracy: 0.3950 - val_loss: 1.6983 - learning_rate: 0.0010
# Epoch 16/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4289 - loss: 1.5949
# Epoch 16: val_loss improved from 1.66196 to 1.62974, saving model to model_fold_4.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4289 - loss: 1.5949 - val_accuracy: 0.4267 - val_loss: 1.6297 - learning_rate: 0.0010
# Epoch 17/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4283 - loss: 1.5943
# Epoch 17: val_loss did not improve from 1.62974
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4284 - loss: 1.5942 - val_accuracy: 0.4108 - val_loss: 1.6737 - learning_rate: 0.0010
# Epoch 18/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4422 - loss: 1.5585
# Epoch 18: val_loss improved from 1.62974 to 1.58745, saving model to model_fold_4.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4421 - loss: 1.5585 - val_accuracy: 0.4258 - val_loss: 1.5875 - learning_rate: 0.0010
# Epoch 19/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4434 - loss: 1.5335
# Epoch 19: val_loss did not improve from 1.58745
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4433 - loss: 1.5336 - val_accuracy: 0.4332 - val_loss: 1.6019 - learning_rate: 0.0010
# Epoch 20/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4584 - loss: 1.5002
# Epoch 20: val_loss improved from 1.58745 to 1.57843, saving model to model_fold_4.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4583 - loss: 1.5006 - val_accuracy: 0.4332 - val_loss: 1.5784 - learning_rate: 0.0010
# Epoch 21/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4586 - loss: 1.5068
# Epoch 21: val_loss did not improve from 1.57843
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4586 - loss: 1.5066 - val_accuracy: 0.4080 - val_loss: 1.6421 - learning_rate: 0.0010
# Epoch 22/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4696 - loss: 1.5021
# Epoch 22: val_loss did not improve from 1.57843
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4697 - loss: 1.5019 - val_accuracy: 0.4538 - val_loss: 1.5893 - learning_rate: 0.0010
# Epoch 23/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4746 - loss: 1.4786
# Epoch 23: val_loss did not improve from 1.57843
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4745 - loss: 1.4786 - val_accuracy: 0.4211 - val_loss: 1.6746 - learning_rate: 0.0010
# Epoch 24/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4803 - loss: 1.4540
# Epoch 24: val_loss improved from 1.57843 to 1.56164, saving model to model_fold_4.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4802 - loss: 1.4538 - val_accuracy: 0.4519 - val_loss: 1.5616 - learning_rate: 0.0010
# Epoch 25/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4919 - loss: 1.4029
# Epoch 25: val_loss did not improve from 1.56164
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4919 - loss: 1.4031 - val_accuracy: 0.4454 - val_loss: 1.5856 - learning_rate: 0.0010
# Epoch 26/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5044 - loss: 1.3815
# Epoch 26: val_loss improved from 1.56164 to 1.54693, saving model to model_fold_4.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5042 - loss: 1.3819 - val_accuracy: 0.4547 - val_loss: 1.5469 - learning_rate: 0.0010
# Epoch 27/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5041 - loss: 1.3727
# Epoch 27: val_loss improved from 1.54693 to 1.52084, saving model to model_fold_4.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5041 - loss: 1.3729 - val_accuracy: 0.4697 - val_loss: 1.5208 - learning_rate: 0.0010
# Epoch 28/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5176 - loss: 1.3430
# Epoch 28: val_loss did not improve from 1.52084
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5174 - loss: 1.3434 - val_accuracy: 0.4659 - val_loss: 1.5231 - learning_rate: 0.0010
# Epoch 29/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5106 - loss: 1.3324
# Epoch 29: val_loss improved from 1.52084 to 1.51704, saving model to model_fold_4.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5106 - loss: 1.3326 - val_accuracy: 0.4622 - val_loss: 1.5170 - learning_rate: 0.0010
# Epoch 30/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5272 - loss: 1.3446
# Epoch 30: val_loss did not improve from 1.51704
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5270 - loss: 1.3448 - val_accuracy: 0.4444 - val_loss: 1.5742 - learning_rate: 0.0010
# Epoch 31/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5411 - loss: 1.2827
# Epoch 31: val_loss did not improve from 1.51704
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5408 - loss: 1.2831 - val_accuracy: 0.4566 - val_loss: 1.5218 - learning_rate: 0.0010
# Epoch 32/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5361 - loss: 1.2946
# Epoch 32: val_loss improved from 1.51704 to 1.46987, saving model to model_fold_4.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5360 - loss: 1.2947 - val_accuracy: 0.4883 - val_loss: 1.4699 - learning_rate: 0.0010
# Epoch 33/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5438 - loss: 1.2668
# Epoch 33: val_loss did not improve from 1.46987
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5438 - loss: 1.2669 - val_accuracy: 0.4725 - val_loss: 1.5281 - learning_rate: 0.0010
# Epoch 34/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5393 - loss: 1.2679
# Epoch 34: val_loss did not improve from 1.46987
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5392 - loss: 1.2681 - val_accuracy: 0.4827 - val_loss: 1.5190 - learning_rate: 0.0010
# Epoch 35/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5614 - loss: 1.2035
# Epoch 35: val_loss did not improve from 1.46987
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5612 - loss: 1.2041 - val_accuracy: 0.4930 - val_loss: 1.4806 - learning_rate: 0.0010
# Epoch 36/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5657 - loss: 1.2246
# Epoch 36: val_loss did not improve from 1.46987
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5657 - loss: 1.2248 - val_accuracy: 0.4267 - val_loss: 1.6325 - learning_rate: 0.0010
# Epoch 37/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5819 - loss: 1.1991
# Epoch 37: val_loss did not improve from 1.46987
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5816 - loss: 1.1995 - val_accuracy: 0.4827 - val_loss: 1.5093 - learning_rate: 0.0010
# Epoch 38/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5645 - loss: 1.1864
# Epoch 38: val_loss did not improve from 1.46987
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5644 - loss: 1.1870 - val_accuracy: 0.4818 - val_loss: 1.5259 - learning_rate: 0.0010
# Epoch 39/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5924 - loss: 1.1650
# Epoch 39: val_loss did not improve from 1.46987
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5923 - loss: 1.1652 - val_accuracy: 0.4799 - val_loss: 1.5729 - learning_rate: 0.0010
# Epoch 40/40
# ...
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4588 - loss: 1.4952 - val_accuracy: 0.4136 - val_loss: 1.5796 - learning_rate: 0.0010
# Epoch 28/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4646 - loss: 1.4838
# Epoch 28: val_loss did not improve from 1.52732
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4646 - loss: 1.4841 - val_accuracy: 0.4426 - val_loss: 1.5297 - learning_rate: 0.0010
# Epoch 29/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4648 - loss: 1.4790
# Epoch 29: val_loss did not improve from 1.52732
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4647 - loss: 1.4792 - val_accuracy: 0.4370 - val_loss: 1.5861 - learning_rate: 0.0010
# Epoch 30/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4681 - loss: 1.4469
# Epoch 30: val_loss did not improve from 1.52732
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4679 - loss: 1.4478 - val_accuracy: 0.4136 - val_loss: 1.6015 - learning_rate: 0.0010
# Epoch 31/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4780 - loss: 1.4354
# Epoch 31: val_loss did not improve from 1.52732
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4780 - loss: 1.4355 - val_accuracy: 0.4332 - val_loss: 1.5862 - learning_rate: 0.0010
# Epoch 32/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4743 - loss: 1.4503
# Epoch 32: val_loss did not improve from 1.52732
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4744 - loss: 1.4497 - val_accuracy: 0.4556 - val_loss: 1.5556 - learning_rate: 0.0010
# Epoch 33/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4982 - loss: 1.3793
# Epoch 33: val_loss improved from 1.52732 to 1.44610, saving model to model_fold_6.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4985 - loss: 1.3788 - val_accuracy: 0.4874 - val_loss: 1.4461 - learning_rate: 5.0000e-04
# Epoch 34/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5161 - loss: 1.3104
# Epoch 34: val_loss improved from 1.44610 to 1.42847, saving model to model_fold_6.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5162 - loss: 1.3104 - val_accuracy: 0.4865 - val_loss: 1.4285 - learning_rate: 5.0000e-04
# Epoch 35/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5244 - loss: 1.2951
# Epoch 35: val_loss did not improve from 1.42847
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5245 - loss: 1.2950 - val_accuracy: 0.4734 - val_loss: 1.4573 - learning_rate: 5.0000e-04
# Epoch 36/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5349 - loss: 1.2908
# Epoch 36: val_loss did not improve from 1.42847
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5349 - loss: 1.2905 - val_accuracy: 0.4809 - val_loss: 1.4848 - learning_rate: 5.0000e-04
# Epoch 37/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5497 - loss: 1.2489
# Epoch 37: val_loss did not improve from 1.42847
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5497 - loss: 1.2491 - val_accuracy: 0.4809 - val_loss: 1.4582 - learning_rate: 5.0000e-04
# Epoch 38/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5538 - loss: 1.2268
# Epoch 38: val_loss did not improve from 1.42847
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5537 - loss: 1.2270 - val_accuracy: 0.4893 - val_loss: 1.4504 - learning_rate: 5.0000e-04
# Epoch 39/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5706 - loss: 1.2068
# Epoch 39: val_loss did not improve from 1.42847
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5704 - loss: 1.2068 - val_accuracy: 0.5107 - val_loss: 1.4397 - learning_rate: 5.0000e-04
# Epoch 40/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5611 - loss: 1.1978
# Epoch 40: val_loss improved from 1.42847 to 1.40719, saving model to model_fold_6.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5612 - loss: 1.1978 - val_accuracy: 0.5061 - val_loss: 1.4072 - learning_rate: 5.0000e-04
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5120 - loss: 1.4086
# Fold 6 - Accuracy: 50.61% - Loss: 1.4072
# Epoch 1/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.1220 - loss: 25.3135
# Epoch 1: val_loss improved from inf to 2.18768, saving model to model_fold_7.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 17s 47ms/step - accuracy: 0.1221 - loss: 25.2232 - val_accuracy: 0.1494 - val_loss: 2.1877 - learning_rate: 0.0010
# Epoch 2/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1725 - loss: 2.1391
# Epoch 2: val_loss improved from 2.18768 to 2.06323, saving model to model_fold_7.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.1726 - loss: 2.1387 - val_accuracy: 0.1989 - val_loss: 2.0632 - learning_rate: 0.0010
# Epoch 3/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2241 - loss: 2.0386
# Epoch 3: val_loss did not improve from 2.06323
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.2242 - loss: 2.0386 - val_accuracy: 0.2204 - val_loss: 2.0908 - learning_rate: 0.0010
# Epoch 4/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2541 - loss: 1.9872
# Epoch 4: val_loss improved from 2.06323 to 1.99186, saving model to model_fold_7.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.2541 - loss: 1.9869 - val_accuracy: 0.2773 - val_loss: 1.9919 - learning_rate: 0.0010
# Epoch 5/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2780 - loss: 1.9043
# Epoch 5: val_loss improved from 1.99186 to 1.87753, saving model to model_fold_7.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.2780 - loss: 1.9042 - val_accuracy: 0.2969 - val_loss: 1.8775 - learning_rate: 0.0010
# Epoch 6/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2747 - loss: 1.8727
# Epoch 6: val_loss improved from 1.87753 to 1.85142, saving model to model_fold_7.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.2751 - loss: 1.8724 - val_accuracy: 0.2951 - val_loss: 1.8514 - learning_rate: 0.0010
# Epoch 7/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3229 - loss: 1.8140
# Epoch 7: val_loss did not improve from 1.85142
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3229 - loss: 1.8140 - val_accuracy: 0.3156 - val_loss: 1.8700 - learning_rate: 0.0010
# Epoch 8/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3238 - loss: 1.8144
# Epoch 8: val_loss improved from 1.85142 to 1.75389, saving model to model_fold_7.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3240 - loss: 1.8138 - val_accuracy: 0.3324 - val_loss: 1.7539 - learning_rate: 0.0010
# Epoch 9/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3689 - loss: 1.7077
# Epoch 9: val_loss improved from 1.75389 to 1.72295, saving model to model_fold_7.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3690 - loss: 1.7078 - val_accuracy: 0.3576 - val_loss: 1.7229 - learning_rate: 0.0010
# Epoch 10/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3658 - loss: 1.6902
# Epoch 10: val_loss did not improve from 1.72295
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3658 - loss: 1.6902 - val_accuracy: 0.3567 - val_loss: 1.7449 - learning_rate: 0.0010
# Epoch 11/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3852 - loss: 1.6569
# Epoch 11: val_loss did not improve from 1.72295
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3854 - loss: 1.6570 - val_accuracy: 0.3380 - val_loss: 1.8016 - learning_rate: 0.0010
# Epoch 12/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4021 - loss: 1.6311
# Epoch 12: val_loss improved from 1.72295 to 1.65217, saving model to model_fold_7.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4021 - loss: 1.6312 - val_accuracy: 0.3987 - val_loss: 1.6522 - learning_rate: 0.0010
# Epoch 13/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4189 - loss: 1.6118
# Epoch 13: val_loss did not improve from 1.65217
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4188 - loss: 1.6118 - val_accuracy: 0.3754 - val_loss: 1.6678 - learning_rate: 0.0010
# Epoch 14/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4359 - loss: 1.5669
# Epoch 14: val_loss did not improve from 1.65217
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4355 - loss: 1.5675 - val_accuracy: 0.3585 - val_loss: 1.7783 - learning_rate: 0.0010
# Epoch 15/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4158 - loss: 1.6069
# Epoch 15: val_loss did not improve from 1.65217
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4158 - loss: 1.6068 - val_accuracy: 0.3641 - val_loss: 1.7854 - learning_rate: 0.0010
# Epoch 16/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4285 - loss: 1.5491
# Epoch 16: val_loss did not improve from 1.65217
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4286 - loss: 1.5491 - val_accuracy: 0.3697 - val_loss: 1.7024 - learning_rate: 0.0010
# Epoch 17/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4508 - loss: 1.5169
# Epoch 17: val_loss improved from 1.65217 to 1.62234, saving model to model_fold_7.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4507 - loss: 1.5170 - val_accuracy: 0.4015 - val_loss: 1.6223 - learning_rate: 0.0010
# Epoch 18/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4437 - loss: 1.5141
# Epoch 18: val_loss improved from 1.62234 to 1.61479, saving model to model_fold_7.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4436 - loss: 1.5143 - val_accuracy: 0.3959 - val_loss: 1.6148 - learning_rate: 0.0010
# Epoch 19/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4432 - loss: 1.5203
# Epoch 19: val_loss did not improve from 1.61479
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4432 - loss: 1.5203 - val_accuracy: 0.4155 - val_loss: 1.6636 - learning_rate: 0.0010
# Epoch 20/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4544 - loss: 1.4810
# Epoch 20: val_loss did not improve from 1.61479
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4546 - loss: 1.4809 - val_accuracy: 0.4164 - val_loss: 1.6482 - learning_rate: 0.0010
# Epoch 21/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4688 - loss: 1.4639
# Epoch 21: val_loss did not improve from 1.61479
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4686 - loss: 1.4643 - val_accuracy: 0.3856 - val_loss: 1.7045 - learning_rate: 0.0010
# Epoch 22/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4780 - loss: 1.4582
# Epoch 22: val_loss did not improve from 1.61479
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4779 - loss: 1.4582 - val_accuracy: 0.4006 - val_loss: 1.7081 - learning_rate: 0.0010
# Epoch 23/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4934 - loss: 1.4218
# Epoch 23: val_loss did not improve from 1.61479
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4933 - loss: 1.4221 - val_accuracy: 0.4267 - val_loss: 1.6339 - learning_rate: 0.0010
# Epoch 24/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4961 - loss: 1.4133
# Epoch 24: val_loss improved from 1.61479 to 1.57800, saving model to model_fold_7.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.4961 - loss: 1.4132 - val_accuracy: 0.4388 - val_loss: 1.5780 - learning_rate: 0.0010
# Epoch 25/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5010 - loss: 1.4052
# Epoch 25: val_loss did not improve from 1.57800
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5006 - loss: 1.4057 - val_accuracy: 0.4211 - val_loss: 1.6496 - learning_rate: 0.0010
# Epoch 26/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4992 - loss: 1.3873
# Epoch 26: val_loss did not improve from 1.57800
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4992 - loss: 1.3873 - val_accuracy: 0.4230 - val_loss: 1.6069 - learning_rate: 0.0010
# Epoch 27/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5033 - loss: 1.3799
# Epoch 27: val_loss did not improve from 1.57800
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5032 - loss: 1.3801 - val_accuracy: 0.4463 - val_loss: 1.6007 - learning_rate: 0.0010
# Epoch 28/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5033 - loss: 1.3546
# Epoch 28: val_loss did not improve from 1.57800
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5033 - loss: 1.3547 - val_accuracy: 0.4267 - val_loss: 1.6395 - learning_rate: 0.0010
# Epoch 29/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5222 - loss: 1.3208
# Epoch 29: val_loss did not improve from 1.57800
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5219 - loss: 1.3215 - val_accuracy: 0.4398 - val_loss: 1.6326 - learning_rate: 0.0010
# Epoch 30/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5412 - loss: 1.2912
# Epoch 30: val_loss improved from 1.57800 to 1.51747, saving model to model_fold_7.weights.h5
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5411 - loss: 1.2915 - val_accuracy: 0.4603 - val_loss: 1.5175 - learning_rate: 0.0010
# Epoch 31/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5194 - loss: 1.3100
# Epoch 31: val_loss did not improve from 1.51747
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5194 - loss: 1.3102 - val_accuracy: 0.4463 - val_loss: 1.5667 - learning_rate: 0.0010
# Epoch 32/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5401 - loss: 1.2934
# Epoch 32: val_loss did not improve from 1.51747
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5400 - loss: 1.2934 - val_accuracy: 0.4725 - val_loss: 1.5645 - learning_rate: 0.0010
# Epoch 33/40
# 199/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5441 - loss: 1.2528
# Epoch 33: val_loss did not improve from 1.51747
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5441 - loss: 1.2532 - val_accuracy: 0.4669 - val_loss: 1.5323 - learning_rate: 0.0010
# Epoch 34/40
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5385 - loss: 1.2839
# Epoch 34: val_loss did not improve from 1.51747
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5385 - loss: 1.2838 - val_accuracy: 0.4706 - val_loss: 1.5412 - learning_rate: 0.0010
# Epoch 35/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5648 - loss: 1.2018
# Epoch 35: val_loss did not improve from 1.51747
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5646 - loss: 1.2026 - val_accuracy: 0.4603 - val_loss: 1.6467 - learning_rate: 0.0010
# Epoch 36/40
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5647 - loss: 1.2063
# Epoch 36: val_loss did not improve from 1.51747
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5647 - loss: 1.2064 - val_accuracy: 0.4416 - val_loss: 1.6004 - learning_rate: 0.0010
# Epoch 37/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5638 - loss: 1.2016
# Epoch 37: val_loss did not improve from 1.51747
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5638 - loss: 1.2021 - val_accuracy: 0.4641 - val_loss: 1.5800 - learning_rate: 0.0010
# Epoch 38/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5666 - loss: 1.1943
# Epoch 38: val_loss did not improve from 1.51747
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5666 - loss: 1.1948 - val_accuracy: 0.4613 - val_loss: 1.6325 - learning_rate: 0.0010
# Epoch 39/40
# 198/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5807 - loss: 1.1652
# Epoch 39: val_loss did not improve from 1.51747
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5804 - loss: 1.1658 - val_accuracy: 0.4753 - val_loss: 1.6097 - learning_rate: 0.0010
# Epoch 40/40
# 197/201 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5932 - loss: 1.1691
# Epoch 40: val_loss did not improve from 1.51747
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5928 - loss: 1.1697 - val_accuracy: 0.4426 - val_loss: 1.6283 - learning_rate: 0.0010
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4660 - loss: 1.4911
# Fold 7 - Accuracy: 46.03% - Loss: 1.5175
#
# Average Accuracy: 46.49%
# Average Loss: 1.5056

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
# Plotting of accuracy and loss for each fold
for i, history_dict in enumerate(history_dicts):
    acc = history_dict['accuracy']
    val_acc = history_dict['val_accuracy']
    loss = history_dict['loss']
    val_loss = history_dict['val_loss']

    plt.figure(figsize=(12, 6))

    # Accuracy graph
    plt.subplot(1, 2, 1)
    plt.plot(acc, label='Accuracy (train)')
    plt.plot(val_acc, label='Accuracy (validation)')
    plt.title(f'Model Accuracy - Fold {i+1}')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Loss graph
    plt.subplot(1, 2, 2)
    plt.plot(loss, label='Loss (train)')
    plt.plot(val_loss, label='Loss (validation)')
    plt.title(f'Model Loss - Fold {i+1}')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
# Classfification report
y_pred_probs = model.predict(val_images)
y_pred = np.argmax(y_pred_probs, axis=1)
print("Classification Report:")
print(classification_report(val_labels, y_pred, target_names=class_names, digits=4))
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step
# Classification Report:
#                    precision    recall  f1-score   support
#
#         apple_pie     0.3063    0.3063    0.3063       111
#    baby_back_ribs     0.5152    0.6667    0.5812       102
#           baklava     0.4713    0.3661    0.4121       112
#    beef_carpaccio     0.6706    0.5644    0.6129       101
#      beef_tartare     0.4110    0.5537    0.4718       121
#        beet_salad     0.5773    0.5045    0.5385       111
#          beignets     0.5321    0.5918    0.5604        98
#          bibimbap     0.6505    0.6036    0.6262       111
#     bread_pudding     0.2368    0.1837    0.2069        98
# breakfast_burrito     0.2500    0.2547    0.2523       106
#
#          accuracy                         0.4603      1071
#         macro avg     0.4621    0.4595    0.4569      1071
#      weighted avg     0.4621    0.4603    0.4572      1071

# %%
# Confusion Matrix for the last fold
cm = confusion_matrix(val_labels, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
