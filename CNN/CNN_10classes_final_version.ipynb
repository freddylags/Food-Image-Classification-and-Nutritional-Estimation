# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.18.0

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras import mixed_precision

AUTOTUNE = tf.data.AUTOTUNE

# Load Food-101 dataset (TFDS)
dataset_name = "food101"
(ds_train, ds_test), dataset_info = tfds.load(
    dataset_name,
    split=["train", "validation"],
    as_supervised=True,
    # Load the dataset again (it will reuse the already downloaded and prepared data)
    # data_dir='/root/tensorflow_datasets'  # Optional: specify the directory for TFDS
    with_info=True
)
print("Dataset Loaded and Reused:", dataset_name)

# Récupérer les noms des classes
class_names = dataset_info.features['label'].names[:10]

num_classes = len(class_names)

# Convert class names to indices for filtering
selected_class_indices = {i: i for i in range(num_classes)}


# Function to filter
def filter_classes(image, label):
    return tf.reduce_any(tf.equal(label, list(selected_class_indices.keys())))

ds_train_filtered = ds_train.filter(filter_classes)
ds_test_filtered = ds_test.filter(filter_classes)


# Preprocessing Function (Resizing & Normalisation)
def preprocess(image, label):
    image = tf.image.resize(image, (224, 224)) / 255.0  # Normalisation [0,1]
    return image, label

# Apply preprocessing
ds_train_preprocessed = ds_train_filtered.map(preprocess, num_parallel_calls=AUTOTUNE)
ds_test_preprocessed = ds_test_filtered.map(preprocess, num_parallel_calls=AUTOTUNE)

# Batch et préfetch des données
batch_size = 64
train_ds = ds_train_preprocessed.batch(batch_size).prefetch(tf.data.AUTOTUNE)
val_ds = ds_test_preprocessed.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# Activer l'entraînement en précision mixte
mixed_precision.set_global_policy('mixed_float16')
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/food101/2.0.0 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/food101/2.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/food101/incomplete.T64OHE_2.0.0/food101-train.tfrecord*...:   0%|         …
# Generating validation examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/food101/incomplete.T64OHE_2.0.0/food101-validation.tfrecord*...:   0%|    …
# Dataset food101 downloaded and prepared to /root/tensorflow_datasets/food101/2.0.0. Subsequent calls will reuse this data.
# Dataset Loaded and Reused: food101

# %%
# Cnn model
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (5, 5), strides=1, padding='same', activation='relu', input_shape=(224, 224, 3), kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(32, (5, 5), strides=2, padding='same', activation='relu', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Dropout(0.2),

    tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Dropout(0.2),

    tf.keras.layers.Conv2D(128, (2, 2), padding='same', activation='relu', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(128, (2, 2), padding='same', activation='relu', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Dropout(0.2),

    tf.keras.layers.Conv2D(256, (2, 2), padding='same', activation='relu', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(256, (2, 2), padding='same', activation='relu', kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.GlobalAveragePooling2D(),

    tf.keras.layers.Dense(512, activation="relu", kernel_initializer='he_normal'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.2),

    tf.keras.layers.Dense(len(class_names), activation="softmax", dtype='float32')  # dtype='float32' to avoid errors Mixed Precision
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# model compilation
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
# Display the model structure
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 224, 224, 32)        │           2,432 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 224, 224, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 112, 112, 32)        │          25,632 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 112, 112, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 56, 56, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 56, 56, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 56, 56, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 56, 56, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 56, 56, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 56, 56, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 28, 28, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 28, 28, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 28, 28, 128)         │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 28, 28, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 28, 28, 128)         │          65,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 28, 28, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 14, 14, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 14, 14, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 14, 14, 256)         │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 14, 14, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 14, 14, 256)         │         262,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 14, 14, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 256)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_8                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           5,130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 718,378 (2.74 MB)
#  Trainable params: 715,434 (2.73 MB)
#  Non-trainable params: 2,944 (11.50 KB)

# %%
# Callbacks to get a better training
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
#early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Training of the model
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=60,
    callbacks=[lr_scheduler] #early_stopping
)
model.save("cnn_food101_10classes__v2.h5")

print("model save under 'cnn_food101_10classes.h5'")
# Out:
# Epoch 1/60
#     118/Unknown 55s 229ms/step - accuracy: 0.2437 - loss: 2.4146
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 66s 324ms/step - accuracy: 0.2441 - loss: 2.4125 - val_accuracy: 0.1196 - val_loss: 4.0138 - learning_rate: 0.0010
# Epoch 2/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 20s 171ms/step - accuracy: 0.3723 - loss: 1.8760 - val_accuracy: 0.1352 - val_loss: 3.0193 - learning_rate: 0.0010
# Epoch 3/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.4306 - loss: 1.6513 - val_accuracy: 0.2776 - val_loss: 2.1748 - learning_rate: 0.0010
# Epoch 4/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.4738 - loss: 1.5268 - val_accuracy: 0.4124 - val_loss: 1.8022 - learning_rate: 0.0010
# Epoch 5/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 20s 170ms/step - accuracy: 0.5085 - loss: 1.4338 - val_accuracy: 0.4644 - val_loss: 1.6434 - learning_rate: 0.0010
# Epoch 6/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.5458 - loss: 1.3123 - val_accuracy: 0.4600 - val_loss: 1.8723 - learning_rate: 0.0010
# Epoch 7/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 20s 170ms/step - accuracy: 0.5710 - loss: 1.2440 - val_accuracy: 0.3940 - val_loss: 1.8810 - learning_rate: 0.0010
# Epoch 8/60
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.5833 - loss: 1.1900
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.5835 - loss: 1.1892 - val_accuracy: 0.4264 - val_loss: 2.0019 - learning_rate: 0.0010
# Epoch 9/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.6267 - loss: 1.0778 - val_accuracy: 0.5080 - val_loss: 1.5731 - learning_rate: 5.0000e-04
# Epoch 10/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 20s 170ms/step - accuracy: 0.6659 - loss: 0.9645 - val_accuracy: 0.4572 - val_loss: 1.9042 - learning_rate: 5.0000e-04
# Epoch 11/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 20s 170ms/step - accuracy: 0.6836 - loss: 0.9243 - val_accuracy: 0.4944 - val_loss: 1.8546 - learning_rate: 5.0000e-04
# Epoch 12/60
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.7059 - loss: 0.8519
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 157ms/step - accuracy: 0.7061 - loss: 0.8512 - val_accuracy: 0.5168 - val_loss: 1.7290 - learning_rate: 5.0000e-04
# Epoch 13/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 159ms/step - accuracy: 0.7216 - loss: 0.7873 - val_accuracy: 0.6656 - val_loss: 1.0027 - learning_rate: 2.5000e-04
# Epoch 14/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 157ms/step - accuracy: 0.7485 - loss: 0.7133 - val_accuracy: 0.6664 - val_loss: 1.0481 - learning_rate: 2.5000e-04
# Epoch 15/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 159ms/step - accuracy: 0.7600 - loss: 0.6749 - val_accuracy: 0.6772 - val_loss: 0.9927 - learning_rate: 2.5000e-04
# Epoch 16/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 157ms/step - accuracy: 0.7877 - loss: 0.6244 - val_accuracy: 0.6636 - val_loss: 1.0934 - learning_rate: 2.5000e-04
# Epoch 17/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 159ms/step - accuracy: 0.7962 - loss: 0.5967 - val_accuracy: 0.6700 - val_loss: 1.0256 - learning_rate: 2.5000e-04
# Epoch 18/60
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.7964 - loss: 0.5763
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 157ms/step - accuracy: 0.7966 - loss: 0.5759 - val_accuracy: 0.6612 - val_loss: 1.1315 - learning_rate: 2.5000e-04
# Epoch 19/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 159ms/step - accuracy: 0.8267 - loss: 0.5040 - val_accuracy: 0.6924 - val_loss: 1.0148 - learning_rate: 1.2500e-04
# Epoch 20/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 158ms/step - accuracy: 0.8427 - loss: 0.4665 - val_accuracy: 0.6792 - val_loss: 1.0459 - learning_rate: 1.2500e-04
# Epoch 21/60
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8453 - loss: 0.4464
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 158ms/step - accuracy: 0.8454 - loss: 0.4461 - val_accuracy: 0.6868 - val_loss: 1.0436 - learning_rate: 1.2500e-04
# Epoch 22/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 158ms/step - accuracy: 0.8636 - loss: 0.4068 - val_accuracy: 0.7048 - val_loss: 0.9867 - learning_rate: 6.2500e-05
# Epoch 23/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 157ms/step - accuracy: 0.8719 - loss: 0.3855 - val_accuracy: 0.6984 - val_loss: 1.0008 - learning_rate: 6.2500e-05
# Epoch 24/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 161ms/step - accuracy: 0.8738 - loss: 0.3784 - val_accuracy: 0.6948 - val_loss: 1.0207 - learning_rate: 6.2500e-05
# Epoch 25/60
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8812 - loss: 0.3662
# Epoch 25: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 159ms/step - accuracy: 0.8813 - loss: 0.3659 - val_accuracy: 0.6916 - val_loss: 1.0508 - learning_rate: 6.2500e-05
# Epoch 26/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 161ms/step - accuracy: 0.8795 - loss: 0.3623 - val_accuracy: 0.7096 - val_loss: 0.9990 - learning_rate: 3.1250e-05
# Epoch 27/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 159ms/step - accuracy: 0.8772 - loss: 0.3574 - val_accuracy: 0.7040 - val_loss: 1.0204 - learning_rate: 3.1250e-05
# Epoch 28/60
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8855 - loss: 0.3413
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 160ms/step - accuracy: 0.8857 - loss: 0.3410 - val_accuracy: 0.7020 - val_loss: 1.0158 - learning_rate: 3.1250e-05
# Epoch 29/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 158ms/step - accuracy: 0.8918 - loss: 0.3312 - val_accuracy: 0.7128 - val_loss: 0.9841 - learning_rate: 1.5625e-05
# Epoch 30/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 160ms/step - accuracy: 0.8907 - loss: 0.3230 - val_accuracy: 0.7160 - val_loss: 0.9853 - learning_rate: 1.5625e-05
# Epoch 31/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 159ms/step - accuracy: 0.8966 - loss: 0.3191 - val_accuracy: 0.7144 - val_loss: 0.9977 - learning_rate: 1.5625e-05
# Epoch 32/60
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8939 - loss: 0.3195
# Epoch 32: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 158ms/step - accuracy: 0.8940 - loss: 0.3193 - val_accuracy: 0.7112 - val_loss: 1.0044 - learning_rate: 1.5625e-05
# Epoch 33/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 160ms/step - accuracy: 0.8912 - loss: 0.3205 - val_accuracy: 0.7144 - val_loss: 0.9921 - learning_rate: 7.8125e-06
# Epoch 34/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 157ms/step - accuracy: 0.9009 - loss: 0.3093 - val_accuracy: 0.7152 - val_loss: 0.9940 - learning_rate: 7.8125e-06
# Epoch 35/60
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9002 - loss: 0.3047
# Epoch 35: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 160ms/step - accuracy: 0.9003 - loss: 0.3044 - val_accuracy: 0.7140 - val_loss: 0.9995 - learning_rate: 7.8125e-06
# Epoch 36/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 157ms/step - accuracy: 0.9022 - loss: 0.3026 - val_accuracy: 0.7148 - val_loss: 1.0011 - learning_rate: 3.9063e-06
# Epoch 37/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 160ms/step - accuracy: 0.8988 - loss: 0.3048 - val_accuracy: 0.7168 - val_loss: 0.9957 - learning_rate: 3.9063e-06
# Epoch 38/60
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9037 - loss: 0.2972
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 158ms/step - accuracy: 0.9038 - loss: 0.2970 - val_accuracy: 0.7152 - val_loss: 0.9967 - learning_rate: 3.9063e-06
# Epoch 39/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 159ms/step - accuracy: 0.8978 - loss: 0.3116 - val_accuracy: 0.7152 - val_loss: 0.9975 - learning_rate: 1.9531e-06
# Epoch 40/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 157ms/step - accuracy: 0.8998 - loss: 0.2963 - val_accuracy: 0.7160 - val_loss: 0.9969 - learning_rate: 1.9531e-06
# Epoch 41/60
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9047 - loss: 0.3029
# Epoch 41: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 159ms/step - accuracy: 0.9048 - loss: 0.3027 - val_accuracy: 0.7164 - val_loss: 0.9951 - learning_rate: 1.9531e-06
# Epoch 42/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 159ms/step - accuracy: 0.9051 - loss: 0.2982 - val_accuracy: 0.7148 - val_loss: 0.9983 - learning_rate: 9.7656e-07
# Epoch 43/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 159ms/step - accuracy: 0.9031 - loss: 0.3024 - val_accuracy: 0.7156 - val_loss: 0.9991 - learning_rate: 9.7656e-07
# Epoch 44/60
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9099 - loss: 0.2912
# Epoch 44: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 159ms/step - accuracy: 0.9099 - loss: 0.2911 - val_accuracy: 0.7148 - val_loss: 1.0010 - learning_rate: 9.7656e-07
# Epoch 45/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 157ms/step - accuracy: 0.9081 - loss: 0.2963 - val_accuracy: 0.7148 - val_loss: 1.0004 - learning_rate: 4.8828e-07
# Epoch 46/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 21s 176ms/step - accuracy: 0.9082 - loss: 0.2909 - val_accuracy: 0.7140 - val_loss: 1.0017 - learning_rate: 4.8828e-07
# Epoch 47/60
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9090 - loss: 0.2948
# Epoch 47: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 157ms/step - accuracy: 0.9090 - loss: 0.2946 - val_accuracy: 0.7156 - val_loss: 1.0014 - learning_rate: 4.8828e-07
# Epoch 48/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 159ms/step - accuracy: 0.9072 - loss: 0.2938 - val_accuracy: 0.7140 - val_loss: 0.9997 - learning_rate: 2.4414e-07
# Epoch 49/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 158ms/step - accuracy: 0.9104 - loss: 0.2976 - val_accuracy: 0.7148 - val_loss: 1.0001 - learning_rate: 2.4414e-07
# Epoch 50/60
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9016 - loss: 0.3027
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 159ms/step - accuracy: 0.9018 - loss: 0.3025 - val_accuracy: 0.7152 - val_loss: 1.0007 - learning_rate: 2.4414e-07
# Epoch 51/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 159ms/step - accuracy: 0.9062 - loss: 0.2891 - val_accuracy: 0.7156 - val_loss: 0.9999 - learning_rate: 1.2207e-07
# Epoch 52/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 159ms/step - accuracy: 0.9067 - loss: 0.3003 - val_accuracy: 0.7148 - val_loss: 1.0009 - learning_rate: 1.2207e-07
# Epoch 53/60
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9043 - loss: 0.2943
# Epoch 53: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 159ms/step - accuracy: 0.9044 - loss: 0.2941 - val_accuracy: 0.7152 - val_loss: 1.0004 - learning_rate: 1.2207e-07
# Epoch 54/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 159ms/step - accuracy: 0.9081 - loss: 0.2960 - val_accuracy: 0.7156 - val_loss: 1.0000 - learning_rate: 6.1035e-08
# Epoch 55/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 160ms/step - accuracy: 0.9098 - loss: 0.2981 - val_accuracy: 0.7148 - val_loss: 0.9991 - learning_rate: 6.1035e-08
# Epoch 56/60
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9097 - loss: 0.2908
# Epoch 56: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 158ms/step - accuracy: 0.9098 - loss: 0.2906 - val_accuracy: 0.7148 - val_loss: 1.0003 - learning_rate: 6.1035e-08
# Epoch 57/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 160ms/step - accuracy: 0.9003 - loss: 0.2995 - val_accuracy: 0.7156 - val_loss: 1.0013 - learning_rate: 3.0518e-08
# Epoch 58/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 158ms/step - accuracy: 0.9072 - loss: 0.2939 - val_accuracy: 0.7152 - val_loss: 1.0013 - learning_rate: 3.0518e-08
# Epoch 59/60
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9093 - loss: 0.2916
# Epoch 59: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 161ms/step - accuracy: 0.9094 - loss: 0.2915 - val_accuracy: 0.7160 - val_loss: 1.0016 - learning_rate: 3.0518e-08
# Epoch 60/60
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 19s 158ms/step - accuracy: 0.9065 - loss: 0.2963 - val_accuracy: 0.7152 - val_loss: 1.0011 - learning_rate: 1.5259e-08
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# model save under 'cnn_food101_10classes.h5'

# %%
# Evaluate the model on the validation dataset
test_loss, test_acc = model.evaluate(val_ds)
print(f'\nValidation Accuracy: {test_acc * 100:.2f}%')
print(f'\nValidation Loss: {test_loss:.4f}')
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - accuracy: 0.7207 - loss: 0.9876
#
# Validation Accuracy: 71.52%
#
# Validation Loss: 1.0011

# %%
import matplotlib.pyplot as plt
# Plots of loss and accuracy
history_dict = history.history
acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']
loss = history_dict['loss']
val_loss = history_dict['val_loss']

plt.figure(figsize=(12, 6))

# Accuracy graph
plt.subplot(1, 2, 1)
plt.plot(acc, label='Accuracy (train)')
plt.plot(val_acc, label='Accuracy (validation)')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Loss graph
plt.subplot(1, 2, 2)
plt.plot(loss, label='Loss (train)')
plt.plot(val_loss, label='Loss (validation)')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import numpy as np
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
# Classification report
y_pred_probs = model.predict(val_ds)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.concatenate([y for x, y in val_ds], axis=0)

print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_names, digits=4))
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Classification Report:
#                    precision    recall  f1-score   support
#
#         apple_pie     0.4940    0.3280    0.3942       250
#    baby_back_ribs     0.7992    0.7960    0.7976       250
#           baklava     0.5702    0.8280    0.6754       250
#    beef_carpaccio     0.7374    0.8760    0.8007       250
#      beef_tartare     0.7452    0.7840    0.7641       250
#        beet_salad     0.9048    0.6080    0.7273       250
#          beignets     0.7882    0.9080    0.8439       250
#          bibimbap     0.8861    0.8400    0.8624       250
#     bread_pudding     0.5763    0.5440    0.5597       250
# breakfast_burrito     0.6867    0.6400    0.6625       250
#
#          accuracy                         0.7152      2500
#         macro avg     0.7188    0.7152    0.7088      2500
#      weighted avg     0.7188    0.7152    0.7088      2500

# %%
#confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
import pandas as pd

# classification report
report_dict = classification_report(y_true, y_pred, target_names=class_names, digits=4, output_dict=True)

# dataframe
df = pd.DataFrame(report_dict).transpose()

# saving
df.to_csv("classification_report.csv", index=True)

print("done under 'classification_report.csv'")
# Out:
# done under 'classification_report.csv'

# %%
print('Trainin running time : 1026 seconds')
# Out:
# Trainin running time : 1026 seconds
