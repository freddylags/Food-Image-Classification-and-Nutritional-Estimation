# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np

# Charger le dataset Food-101 (train uniquement)
dataset, info = tfds.load("food101", split="train", as_supervised=True, with_info=True)

# Récupérer les noms des classes
class_names = info.features['label'].names[:10]

# Filtrer le dataset pour ne garder que les 10 premières classes
def filter_classes(image, label):
    return tf.reduce_any([label == i for i in range(10)])

filtered_dataset = dataset.filter(filter_classes)

# Diviser en train/validation (80% - 20%)
train_split = 0.8
dataset_size = sum(1 for _ in filtered_dataset)
train_size = int(train_split * dataset_size)

train_ds = filtered_dataset.take(train_size)
val_ds = filtered_dataset.skip(train_size)

# Fonction de prétraitement des images
def preprocess(image, label):
    image = tf.image.resize(image, (224, 224)) / 255.0  # Normalisation [0,1]
    return image, label

# Appliquer prétraitement
train_ds = train_ds.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
val_ds = val_ds.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)

# Batch et préfetch des données
batch_size = 64
train_ds = train_ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)
# Out:
# Downloading and preparing dataset 4.65 GiB (download: 4.65 GiB, generated: Unknown size, total: 4.65 GiB) to /root/tensorflow_datasets/food101/2.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/75750 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/food101/incomplete.4IEIM4_2.0.0/food101-train.tfrecord*...:   0%|         …
# Generating validation examples...:   0%|          | 0/25250 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/food101/incomplete.4IEIM4_2.0.0/food101-validation.tfrecord*...:   0%|    …
# Dataset food101 downloaded and prepared to /root/tensorflow_datasets/food101/2.0.0. Subsequent calls will reuse this data.

# %%
# Cnn model
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (5, 5), strides=2, padding='same', activation='relu', input_shape=(224, 224, 3), kernel_initializer='he_normal'),
    tf.keras.layers.Conv2D(32, (5, 5), strides=2, padding='same', activation='relu', kernel_initializer='he_normal'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Dropout(0.2),

    tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu', kernel_initializer='he_normal'),
    tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu', kernel_initializer='he_normal'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Dropout(0.2),

    tf.keras.layers.Conv2D(128, (2, 2), padding='same', activation='relu', kernel_initializer='he_normal'),
    tf.keras.layers.Conv2D(128, (2, 2), padding='same', activation='relu', kernel_initializer='he_normal'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Dropout(0.2),

    tf.keras.layers.Conv2D(256, (2, 2), padding='same', activation='relu', kernel_initializer='he_normal'),
    tf.keras.layers.Conv2D(256, (2, 2), padding='same', activation='relu', kernel_initializer='he_normal'),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(512, activation="relu", kernel_initializer='he_normal'),
    tf.keras.layers.Dropout(0.2),

    tf.keras.layers.Dense(len(class_names), activation="softmax", kernel_initializer='he_normal')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# model compilation
model.compile(optimizer='Adam', loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
# plot summary of the model
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 112, 112, 32)        │           2,432 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 56, 56, 32)          │          25,632 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 28, 28, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 28, 28, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 28, 28, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 28, 28, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 14, 14, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 14, 14, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 14, 14, 128)         │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 14, 14, 128)         │          65,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 7, 7, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 7, 7, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 7, 7, 256)           │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 7, 7, 256)           │         262,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 256)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           5,130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 712,490 (2.72 MB)
#  Trainable params: 712,490 (2.72 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Callbacks to save the model
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='model.weights.h5',
    verbose=1,
    save_best_only=True,
    save_weights_only=True
)

# Training of the model
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=100,
    callbacks=[
        checkpoint_callback,
        tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True),
        tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
    ]
)
# Out:
# Epoch 1/100
#      94/Unknown 88s 788ms/step - accuracy: 0.1052 - loss: 2.3486
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 1: val_loss improved from inf to 2.27592, saving model to model.weights.h5
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 169s 2s/step - accuracy: 0.1053 - loss: 2.3482 - val_accuracy: 0.1413 - val_loss: 2.2759 - learning_rate: 0.0010
# Epoch 2/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.1516 - loss: 2.2276
# Epoch 2: val_loss improved from 2.27592 to 2.09329, saving model to model.weights.h5
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 178s 2s/step - accuracy: 0.1517 - loss: 2.2272 - val_accuracy: 0.1867 - val_loss: 2.0933 - learning_rate: 0.0010
# Epoch 3/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 688ms/step - accuracy: 0.1780 - loss: 2.0911
# Epoch 3: val_loss improved from 2.09329 to 2.08716, saving model to model.weights.h5
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 203s 2s/step - accuracy: 0.1780 - loss: 2.0910 - val_accuracy: 0.1840 - val_loss: 2.0872 - learning_rate: 0.0010
# Epoch 4/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 685ms/step - accuracy: 0.1986 - loss: 2.0360
# Epoch 4: val_loss improved from 2.08716 to 2.01039, saving model to model.weights.h5
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - accuracy: 0.1988 - loss: 2.0357 - val_accuracy: 0.2280 - val_loss: 2.0104 - learning_rate: 0.0010
# Epoch 5/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.2599 - loss: 1.9513
# Epoch 5: val_loss improved from 2.01039 to 1.93048, saving model to model.weights.h5
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 199s 2s/step - accuracy: 0.2600 - loss: 1.9510 - val_accuracy: 0.2647 - val_loss: 1.9305 - learning_rate: 0.0010
# Epoch 6/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.2885 - loss: 1.8674
# Epoch 6: val_loss improved from 1.93048 to 1.88985, saving model to model.weights.h5
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - accuracy: 0.2887 - loss: 1.8672 - val_accuracy: 0.2947 - val_loss: 1.8899 - learning_rate: 0.0010
# Epoch 7/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 691ms/step - accuracy: 0.3234 - loss: 1.8054
# Epoch 7: val_loss improved from 1.88985 to 1.78867, saving model to model.weights.h5
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - accuracy: 0.3236 - loss: 1.8050 - val_accuracy: 0.3600 - val_loss: 1.7887 - learning_rate: 0.0010
# Epoch 8/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 687ms/step - accuracy: 0.3550 - loss: 1.7339
# Epoch 8: val_loss did not improve from 1.78867
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - accuracy: 0.3552 - loss: 1.7335 - val_accuracy: 0.3620 - val_loss: 1.7947 - learning_rate: 0.0010
# Epoch 9/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 687ms/step - accuracy: 0.3742 - loss: 1.7084
# Epoch 9: val_loss improved from 1.78867 to 1.75567, saving model to model.weights.h5
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.3744 - loss: 1.7078 - val_accuracy: 0.3833 - val_loss: 1.7557 - learning_rate: 0.0010
# Epoch 10/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 687ms/step - accuracy: 0.3935 - loss: 1.6574
# Epoch 10: val_loss improved from 1.75567 to 1.71873, saving model to model.weights.h5
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - accuracy: 0.3937 - loss: 1.6570 - val_accuracy: 0.4000 - val_loss: 1.7187 - learning_rate: 0.0010
# Epoch 11/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.4033 - loss: 1.6178
# Epoch 11: val_loss improved from 1.71873 to 1.67943, saving model to model.weights.h5
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - accuracy: 0.4036 - loss: 1.6174 - val_accuracy: 0.4060 - val_loss: 1.6794 - learning_rate: 0.0010
# Epoch 12/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 693ms/step - accuracy: 0.4331 - loss: 1.5671
# Epoch 12: val_loss improved from 1.67943 to 1.65240, saving model to model.weights.h5
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - accuracy: 0.4333 - loss: 1.5667 - val_accuracy: 0.4213 - val_loss: 1.6524 - learning_rate: 0.0010
# Epoch 13/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - accuracy: 0.4363 - loss: 1.5506
# Epoch 13: val_loss improved from 1.65240 to 1.62427, saving model to model.weights.h5
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 201s 2s/step - accuracy: 0.4364 - loss: 1.5501 - val_accuracy: 0.4393 - val_loss: 1.6243 - learning_rate: 0.0010
# Epoch 14/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 685ms/step - accuracy: 0.4558 - loss: 1.5014
# Epoch 14: val_loss did not improve from 1.62427
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.4559 - loss: 1.5010 - val_accuracy: 0.4393 - val_loss: 1.6579 - learning_rate: 0.0010
# Epoch 15/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.4661 - loss: 1.4739
# Epoch 15: val_loss improved from 1.62427 to 1.61704, saving model to model.weights.h5
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - accuracy: 0.4662 - loss: 1.4734 - val_accuracy: 0.4587 - val_loss: 1.6170 - learning_rate: 0.0010
# Epoch 16/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 686ms/step - accuracy: 0.4845 - loss: 1.4438
# Epoch 16: val_loss did not improve from 1.61704
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 204s 2s/step - accuracy: 0.4846 - loss: 1.4434 - val_accuracy: 0.4220 - val_loss: 1.7417 - learning_rate: 0.0010
# Epoch 17/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 683ms/step - accuracy: 0.4936 - loss: 1.4399
# Epoch 17: val_loss did not improve from 1.61704
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 201s 2s/step - accuracy: 0.4936 - loss: 1.4394 - val_accuracy: 0.4547 - val_loss: 1.6366 - learning_rate: 0.0010
# Epoch 18/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 679ms/step - accuracy: 0.4963 - loss: 1.3911
# Epoch 18: val_loss did not improve from 1.61704
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - accuracy: 0.4964 - loss: 1.3906 - val_accuracy: 0.4553 - val_loss: 1.6470 - learning_rate: 0.0010
# Epoch 19/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 679ms/step - accuracy: 0.5223 - loss: 1.3414
# Epoch 19: val_loss improved from 1.61704 to 1.59796, saving model to model.weights.h5
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - accuracy: 0.5224 - loss: 1.3410 - val_accuracy: 0.4633 - val_loss: 1.5980 - learning_rate: 0.0010
# Epoch 20/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 676ms/step - accuracy: 0.5384 - loss: 1.2955
# Epoch 20: val_loss improved from 1.59796 to 1.55759, saving model to model.weights.h5
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - accuracy: 0.5385 - loss: 1.2952 - val_accuracy: 0.4773 - val_loss: 1.5576 - learning_rate: 0.0010
# Epoch 21/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 680ms/step - accuracy: 0.5420 - loss: 1.3121
# Epoch 21: val_loss did not improve from 1.55759
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 201s 2s/step - accuracy: 0.5421 - loss: 1.3116 - val_accuracy: 0.4547 - val_loss: 1.6853 - learning_rate: 0.0010
# Epoch 22/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 677ms/step - accuracy: 0.5498 - loss: 1.2560
# Epoch 22: val_loss did not improve from 1.55759
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - accuracy: 0.5500 - loss: 1.2555 - val_accuracy: 0.4787 - val_loss: 1.5859 - learning_rate: 0.0010
# Epoch 23/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 682ms/step - accuracy: 0.5589 - loss: 1.2286
# Epoch 23: val_loss did not improve from 1.55759
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - accuracy: 0.5590 - loss: 1.2281 - val_accuracy: 0.4867 - val_loss: 1.5725 - learning_rate: 0.0010
# Epoch 24/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 686ms/step - accuracy: 0.5641 - loss: 1.2037
# Epoch 24: val_loss improved from 1.55759 to 1.50248, saving model to model.weights.h5
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - accuracy: 0.5641 - loss: 1.2035 - val_accuracy: 0.4973 - val_loss: 1.5025 - learning_rate: 0.0010
# Epoch 25/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 678ms/step - accuracy: 0.5728 - loss: 1.1968
# Epoch 25: val_loss did not improve from 1.50248
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - accuracy: 0.5729 - loss: 1.1965 - val_accuracy: 0.5000 - val_loss: 1.5358 - learning_rate: 0.0010
# Epoch 26/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 679ms/step - accuracy: 0.5813 - loss: 1.1666
# Epoch 26: val_loss did not improve from 1.50248
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.5813 - loss: 1.1663 - val_accuracy: 0.5080 - val_loss: 1.5036 - learning_rate: 0.0010
# Epoch 27/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 676ms/step - accuracy: 0.5956 - loss: 1.1437
# Epoch 27: val_loss improved from 1.50248 to 1.49937, saving model to model.weights.h5
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - accuracy: 0.5957 - loss: 1.1434 - val_accuracy: 0.5060 - val_loss: 1.4994 - learning_rate: 0.0010
# Epoch 28/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 686ms/step - accuracy: 0.6074 - loss: 1.1003
# Epoch 28: val_loss did not improve from 1.49937
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - accuracy: 0.6075 - loss: 1.1000 - val_accuracy: 0.4933 - val_loss: 1.5437 - learning_rate: 0.0010
# Epoch 29/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 679ms/step - accuracy: 0.6121 - loss: 1.0982
# Epoch 29: val_loss did not improve from 1.49937
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - accuracy: 0.6121 - loss: 1.0981 - val_accuracy: 0.4813 - val_loss: 1.5859 - learning_rate: 0.0010
# Epoch 30/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 687ms/step - accuracy: 0.6104 - loss: 1.0732
# Epoch 30: val_loss did not improve from 1.49937
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - accuracy: 0.6105 - loss: 1.0730 - val_accuracy: 0.4987 - val_loss: 1.5099 - learning_rate: 0.0010
# Epoch 31/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 680ms/step - accuracy: 0.6354 - loss: 1.0286
# Epoch 31: val_loss did not improve from 1.49937
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - accuracy: 0.6353 - loss: 1.0285 - val_accuracy: 0.4700 - val_loss: 1.6494 - learning_rate: 0.0010
# Epoch 32/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 678ms/step - accuracy: 0.6406 - loss: 1.0117
# Epoch 32: val_loss did not improve from 1.49937
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - accuracy: 0.6406 - loss: 1.0116 - val_accuracy: 0.4967 - val_loss: 1.5702 - learning_rate: 0.0010
# Epoch 33/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.6525 - loss: 0.9568
# Epoch 33: val_loss did not improve from 1.49937
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - accuracy: 0.6525 - loss: 0.9567 - val_accuracy: 0.4920 - val_loss: 1.6120 - learning_rate: 0.0010
# Epoch 34/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 681ms/step - accuracy: 0.6493 - loss: 0.9821
# Epoch 34: val_loss did not improve from 1.49937
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - accuracy: 0.6494 - loss: 0.9818 - val_accuracy: 0.4907 - val_loss: 1.5810 - learning_rate: 0.0010
# Epoch 35/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 691ms/step - accuracy: 0.6556 - loss: 0.9628
# Epoch 35: val_loss did not improve from 1.49937
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - accuracy: 0.6557 - loss: 0.9627 - val_accuracy: 0.5033 - val_loss: 1.6365 - learning_rate: 0.0010
# Epoch 36/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 682ms/step - accuracy: 0.6718 - loss: 0.9398
# Epoch 36: val_loss did not improve from 1.49937
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - accuracy: 0.6718 - loss: 0.9399 - val_accuracy: 0.5227 - val_loss: 1.5207 - learning_rate: 0.0010
# Epoch 37/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 689ms/step - accuracy: 0.6852 - loss: 0.8812
# Epoch 37: val_loss did not improve from 1.49937
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - accuracy: 0.6852 - loss: 0.8812 - val_accuracy: 0.5107 - val_loss: 1.5524 - learning_rate: 0.0010
# Epoch 38/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 680ms/step - accuracy: 0.6881 - loss: 0.8375
# Epoch 38: val_loss did not improve from 1.49937
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - accuracy: 0.6882 - loss: 0.8374 - val_accuracy: 0.4967 - val_loss: 1.6022 - learning_rate: 5.0000e-04
# Epoch 39/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 690ms/step - accuracy: 0.7166 - loss: 0.7933
# Epoch 39: val_loss did not improve from 1.49937
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - accuracy: 0.7166 - loss: 0.7931 - val_accuracy: 0.5000 - val_loss: 1.6881 - learning_rate: 5.0000e-04
# Epoch 40/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 682ms/step - accuracy: 0.7360 - loss: 0.7407
# Epoch 40: val_loss did not improve from 1.49937
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - accuracy: 0.7360 - loss: 0.7406 - val_accuracy: 0.4913 - val_loss: 1.7672 - learning_rate: 5.0000e-04
# Epoch 41/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 681ms/step - accuracy: 0.7412 - loss: 0.7292
# Epoch 41: val_loss did not improve from 1.49937
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 199s 2s/step - accuracy: 0.7413 - loss: 0.7289 - val_accuracy: 0.4920 - val_loss: 1.7125 - learning_rate: 5.0000e-04
# Epoch 42/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 683ms/step - accuracy: 0.7510 - loss: 0.7032
# Epoch 42: val_loss did not improve from 1.49937
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - accuracy: 0.7510 - loss: 0.7030 - val_accuracy: 0.5067 - val_loss: 1.7012 - learning_rate: 5.0000e-04
# Epoch 43/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 686ms/step - accuracy: 0.7618 - loss: 0.6583
# Epoch 43: val_loss did not improve from 1.49937
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - accuracy: 0.7619 - loss: 0.6581 - val_accuracy: 0.4967 - val_loss: 1.8280 - learning_rate: 5.0000e-04
# Epoch 44/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.7774 - loss: 0.6250
# Epoch 44: val_loss did not improve from 1.49937
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - accuracy: 0.7774 - loss: 0.6249 - val_accuracy: 0.5027 - val_loss: 1.8306 - learning_rate: 5.0000e-04
# Epoch 45/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 678ms/step - accuracy: 0.7793 - loss: 0.6172
# Epoch 45: val_loss did not improve from 1.49937
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - accuracy: 0.7793 - loss: 0.6170 - val_accuracy: 0.4860 - val_loss: 1.9630 - learning_rate: 5.0000e-04
# Epoch 46/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 682ms/step - accuracy: 0.7731 - loss: 0.6458
# Epoch 46: val_loss did not improve from 1.49937
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - accuracy: 0.7732 - loss: 0.6453 - val_accuracy: 0.4867 - val_loss: 1.9798 - learning_rate: 5.0000e-04
# Epoch 47/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 678ms/step - accuracy: 0.7870 - loss: 0.5926
# Epoch 47: val_loss did not improve from 1.49937
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.7870 - loss: 0.5924 - val_accuracy: 0.4987 - val_loss: 1.9151 - learning_rate: 5.0000e-04

# %%
from google.colab import files
# Download the saved model
files.download('model.weights.h5')

# %%
# model Evaluation
test_loss, test_acc = model.evaluate(val_ds)
print(f'\nAccuracy val: {test_acc * 100:.2f}%')
print(f'\nLoss val: {test_loss:.4f}')
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 77s 665ms/step - accuracy: 0.5048 - loss: 1.4730
#
# Accuracy val: 50.60%
#
# Loss val: 1.4994

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
# Accuracy score calculation
y_pred_probs = model.predict(val_ds)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.concatenate([y for x, y in val_ds], axis=0)
print(f'Accuracy score: {accuracy_score(y_true, y_pred) * 100:.1f}%')
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 77s 666ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Accuracy score: 50.6%

# %%
# Plots of loss and accuracy
history_dict = history.history
acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']
loss = history_dict['loss']
val_loss = history_dict['val_loss']

plt.figure(figsize=(12, 6))

# Accuracy graph
plt.subplot(1, 2, 1)
plt.plot(acc, label='Accuracy (train)')
plt.plot(val_acc, label='Accuracy (validation)')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Loss graph
plt.subplot(1, 2, 2)
plt.plot(loss, label='Loss (train)')
plt.plot(val_loss, label='Loss (validation)')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Classification report
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_names, digits=4))
# Out:
# Classification Report:
#                    precision    recall  f1-score   support
#
#         apple_pie     0.3521    0.1645    0.2242       152
#    baby_back_ribs     0.6324    0.6370    0.6347       135
#           baklava     0.3697    0.6377    0.4681       138
#    beef_carpaccio     0.7317    0.5806    0.6475       155
#      beef_tartare     0.4724    0.3822    0.4225       157
#        beet_salad     0.5787    0.7153    0.6398       144
#          beignets     0.7480    0.5412    0.6280       170
#          bibimbap     0.6486    0.7229    0.6838       166
#     bread_pudding     0.3172    0.3194    0.3183       144
# breakfast_burrito     0.2816    0.3525    0.3131       139
#
#          accuracy                         0.5060      1500
#         macro avg     0.5132    0.5053    0.4980      1500
#      weighted avg     0.5203    0.5060    0.5019      1500

# %%
# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
